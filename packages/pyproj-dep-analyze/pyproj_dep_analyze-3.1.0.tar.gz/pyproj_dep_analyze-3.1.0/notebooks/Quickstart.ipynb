# %% [markdown]
# # pyproj_dep_analyze Quickstart
#
# Install the package (from PyPI or GitHub), then try the CLI and API examples below.

# %% [markdown]
# ## 1) Install latest from GitHub (default)

# %%
# update pip and setuptools
import sys

# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools

# install pyproj_dep_analyze from GitHub (default)
# !{sys.executable} -m pip install --upgrade git+https://github.com/bitranox/pyproj_dep_analyze.git

# %% [markdown]
# ## Or: Install from PyPI (alternative)
# Uncomment and run the cell below if you prefer the PyPI release.

# %%
# !{sys.executable} -m pip install --upgrade pyproj_dep_analyze

# %% [markdown]
# ## 2) CLI: version and help

# %%
# !pyproj_dep_analyze --version
# !pyproj_dep_analyze --help
# !pyproj_dep_analyze info
# !pyproj_dep_analyze hello
# !pyproj_dep_analyze fail

# %% [markdown]
# ## 3) CLI fail without traceback

# %%
# !pyproj_dep_analyze fail

# %% [markdown]
# ## 4) CLI fail with traceback

# %%
# !pyproj_dep_analyze --traceback fail

# %% [markdown]
# ## 5) script fail without traceback

# %%
# !{sys.executable} -m pyproj_dep_analyze fail

# %% [markdown]
# ## 6) script fail with traceback

# %%
# !{sys.executable} -m pyproj_dep_analyze --traceback fail
