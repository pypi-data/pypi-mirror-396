# %% [markdown]
# # lib_detect_testenv Quickstart
#
# Install the package (from PyPI or GitHub), then try the CLI and API examples below.

# %% [markdown]
# ## 1) Install latest from GitHub (default)

# %%
# update pip and setuptools
import sys

# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools

# install lib_detect_testenv from GitHub (default)
# !{sys.executable} -m pip install --upgrade git+https://github.com/bitranox/lib_detect_testenv.git

# %% [markdown]
# ## Or: Install from PyPI (alternative)
# Uncomment and run the cell below if you prefer the PyPI release.

# %%
# !{sys.executable} -m pip install --upgrade lib_detect_testenv

# %% [markdown]
# ## 2) CLI: version and help

# %%
# !lib_detect_testenv --version
# !lib_detect_testenv --help
# !lib_detect_testenv info
# !lib_detect_testenv hello
# !lib_detect_testenv fail

# %% [markdown]
# ## 3) CLI fail without traceback

# %%
# !lib_detect_testenv fail

# %% [markdown]
# ## 4) CLI fail with traceback

# %%
# !lib_detect_testenv --traceback fail

# %% [markdown]
# ## 5) script fail without traceback

# %%
# !{sys.executable} -m lib_detect_testenv fail

# %% [markdown]
# ## 6) script fail with traceback

# %%
# !{sys.executable} -m lib_detect_testenv --traceback fail
