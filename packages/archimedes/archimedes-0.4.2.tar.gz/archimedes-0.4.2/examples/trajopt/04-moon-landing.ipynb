# %% [markdown]
# # Lunar lander
#
# Analytic example from Darby paper on mesh adaptation

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import numpy as np

from archimedes.experimental import coco as cc

# %load_ext autoreload
# %autoreload 2

# %%
nx, nu = 2, 1
x0 = np.array([10.0, -2.0])
xf = np.array([0.0, 0.0])
t0, tf = 0.0, 4.0
g = 1.5


def j(t, x, u, p):
    return u


def f(t, x, u, p):
    return np.array([x[1], -g + u[0]], like=x)


def cost(x0, t0, xf, tf, q, p):
    return q


# Discretize the domain
N = [10]
knots = []

boundary_conditions = [
    cc.start_time(t0),
    cc.initial_condition(x0),
    cc.final_condition(xf),
]

path_constraints = [cc.control_bounds([0.0], [3.0])]

# Define the optimal control problem
ocp = cc.OptimalControlProblem(
    nx=2,
    nu=1,
    ode=f,
    quad=j,
    cost=cost,
    boundary_constraints=boundary_conditions,
    path_constraints=path_constraints,
)


# Linearly interpolate initial guess
def x_guess(t):
    return x0 + (t - t0) * (xf - x0) / (tf - t0)

# %%
# Initial solution
domain = cc.RadauFiniteElements(N=[5], knots=[])
sol = ocp.solve(
    domain,
    t_guess=(t0, tf),
    x_guess=x_guess,
    ipopt={"print_level": 0},
    print_time=0,
)
converged = False
max_iter = 50

# Refine
for i in range(max_iter):
    print(f"\n*** Iteration {i + 1} ***")

    # sol = ocp.solve(domain, t_guess=(t0, tf), x_guess=x_guess)
    # sol = ocp.solve(domain, t_guess=(t0, tf), x_guess=x_guess, print_level=0, print_time=0)
    residuals = cc.midpoint_residuals(ocp, domain, sol)
    converged, domain = cc.refine_mesh_bisection(
        domain,
        residuals,
        eps=1e-6,
        incr=3,
        rho=2,
        verbose=True,
    )
    sol = ocp.solve(
        domain,
        t_guess=(sol.t0, sol.tf),
        x_guess=sol.x,
        u_guess=sol.u,
        ipopt={"print_level": 0},
        print_time=0,
    )

    if converged:
        break
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
#
# *** Iteration 1 ***
# Element 0: residual (max/avg) = 2.55e-01/1.67e-01, max scaled = 1.53e+00
# New domain: [8], knots=[]
#
# *** Iteration 2 ***
# Element 0: residual (max/avg) = 3.91e-02/2.16e-02, max scaled = 1.81e+00
# New domain: [11], knots=[]
#
# *** Iteration 3 ***
# Element 0: residual (max/avg) = 2.71e-02/1.33e-02, max scaled = 2.04e+00
# 	Splitting at τ=0.0
# New domain: [3, 3], knots=[np.float64(0.0)]
#
# *** Iteration 4 ***
# Element 0: residual (max/avg) = 1.60e-01/1.27e-01, max scaled = 1.26e+00
# Element 1: residual (max/avg) = 7.38e-09/5.84e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [6, 3], knots=[np.float64(0.0)]
#
# *** Iteration 5 ***
# Element 0: residual (max/avg) = 4.97e-02/3.04e-02, max scaled = 1.63e+00
# Element 1: residual (max/avg) = 2.42e-09/1.92e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [9, 3], knots=[np.float64(0.0)]
#
# *** Iteration 6 ***
# Element 0: residual (max/avg) = 1.64e-02/8.68e-03, max scaled = 1.89e+00
# Element 1: residual (max/avg) = 2.91e-09/2.32e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [12, 3], knots=[np.float64(0.0)]
#
# *** Iteration 7 ***
# Element 0: residual (max/avg) = 4.59e-03/2.18e-03, max scaled = 2.10e+00
# 	Splitting at τ=-0.5
# Element 1: residual (max/avg) = 3.18e-09/2.55e-09, max scaled = 1.25e+00
# 	Converged
# New domain: [3, 3, 3], knots=[np.float64(-0.5), np.float64(0.0)]
#
# *** Iteration 8 ***
# Element 0: residual (max/avg) = 9.66e-10/7.71e-10, max scaled = 1.25e+00
# 	Converged
# Element 1: residual (max/avg) = 1.01e-02/8.01e-03, max scaled = 1.26e+00
# Element 2: residual (max/avg) = 3.42e-09/2.71e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 6, 3], knots=[np.float64(-0.5), np.float64(0.0)]
#
# *** Iteration 9 ***
# Element 0: residual (max/avg) = 1.06e-09/8.49e-10, max scaled = 1.25e+00
# 	Converged
# Element 1: residual (max/avg) = 7.86e-03/4.81e-03, max scaled = 1.63e+00
# Element 2: residual (max/avg) = 3.13e-09/2.49e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 9, 3], knots=[np.float64(-0.5), np.float64(0.0)]
#
# *** Iteration 10 ***
# Element 0: residual (max/avg) = 3.90e-10/3.09e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 9.76e-03/5.17e-03, max scaled = 1.89e+00
# Element 2: residual (max/avg) = 1.12e-09/8.83e-10, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 12, 3], knots=[np.float64(-0.5), np.float64(0.0)]
#
# *** Iteration 11 ***
# Element 0: residual (max/avg) = 8.69e-10/6.94e-10, max scaled = 1.25e+00
# 	Converged
# Element 1: residual (max/avg) = 4.84e-03/2.30e-03, max scaled = 2.10e+00
# 	Splitting at τ=-0.25
# Element 2: residual (max/avg) = 3.92e-09/3.13e-09, max scaled = 1.25e+00
# 	Converged
# New domain: [3, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 12 ***
# Element 0: residual (max/avg) = 8.74e-10/6.97e-10, max scaled = 1.25e+00
# 	Converged
# Element 1: residual (max/avg) = 8.78e-03/6.96e-03, max scaled = 1.26e+00
# Element 2: residual (max/avg) = 1.09e-08/8.64e-09, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 3.92e-09/3.11e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 6, 3, 3], knots=[np.float64(-0.5), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 13 ***
# Element 0: residual (max/avg) = 8.36e-10/6.68e-10, max scaled = 1.25e+00
# 	Converged
# Element 1: residual (max/avg) = 2.78e-03/1.71e-03, max scaled = 1.63e+00
# Element 2: residual (max/avg) = 1.10e-08/8.69e-09, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 4.09e-09/3.25e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 9, 3, 3], knots=[np.float64(-0.5), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 14 ***
# Element 0: residual (max/avg) = 9.24e-10/7.32e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 1.63e-03/8.61e-04, max scaled = 1.89e+00
# Element 2: residual (max/avg) = 5.20e-09/4.12e-09, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 3.60e-09/2.85e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 12, 3, 3], knots=[np.float64(-0.5), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 15 ***
# Element 0: residual (max/avg) = 1.01e-09/7.98e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 1.09e-03/5.20e-04, max scaled = 2.10e+00
# 	Splitting at τ=-0.375
# Element 2: residual (max/avg) = 3.21e-09/2.54e-09, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 3.26e-09/2.59e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 16 ***
# Element 0: residual (max/avg) = 3.61e-10/2.86e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 3.53e-10/2.80e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 4.22e-04/3.34e-04, max scaled = 1.26e+00
# Element 3: residual (max/avg) = 1.23e-09/9.76e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 1.20e-09/9.50e-10, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 6, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 17 ***
# Element 0: residual (max/avg) = 9.27e-10/7.34e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 7.77e-10/6.15e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 1.16e-03/7.13e-04, max scaled = 1.63e+00
# Element 3: residual (max/avg) = 5.09e-09/4.03e-09, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 3.58e-09/2.84e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 9, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 18 ***
# Element 0: residual (max/avg) = 9.60e-10/7.61e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.65e-10/6.85e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 1.70e-04/8.99e-05, max scaled = 1.89e+00
# Element 3: residual (max/avg) = 4.04e-09/3.20e-09, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 3.43e-09/2.72e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 12, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 19 ***
# Element 0: residual (max/avg) = 9.78e-10/7.75e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 9.19e-10/7.28e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 2.27e-04/1.08e-04, max scaled = 2.10e+00
# 	Splitting at τ=-0.3125
# Element 3: residual (max/avg) = 3.67e-09/2.91e-09, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 3.37e-09/2.67e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 20 ***
# Element 0: residual (max/avg) = 9.71e-10/7.69e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.97e-10/7.11e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 2.41e-04/1.91e-04, max scaled = 1.26e+00
# Element 3: residual (max/avg) = 7.36e-09/5.83e-09, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 3.81e-09/3.02e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 3.39e-09/2.69e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 6, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 21 ***
# Element 0: residual (max/avg) = 9.79e-10/7.75e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 9.20e-10/7.29e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.46e-05/3.96e-05, max scaled = 1.63e+00
# Element 3: residual (max/avg) = 5.68e-09/4.50e-09, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 3.67e-09/2.90e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 3.36e-09/2.67e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 9, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 22 ***
# Element 0: residual (max/avg) = 9.61e-10/7.61e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.66e-10/6.86e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 4.75e-05/2.51e-05, max scaled = 1.89e+00
# Element 3: residual (max/avg) = 1.27e-08/1.01e-08, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 4.04e-09/3.20e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 3.43e-09/2.72e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 12, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 23 ***
# Element 0: residual (max/avg) = 9.66e-10/7.65e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.82e-10/6.98e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.67e-06/3.17e-06, max scaled = 2.10e+00
# 	Splitting at τ=-0.34375
# Element 3: residual (max/avg) = 9.25e-09/7.32e-09, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 3.92e-09/3.10e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 3.41e-09/2.70e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 24 ***
# Element 0: residual (max/avg) = 9.58e-10/7.59e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.59e-10/6.81e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.26e-10/4.96e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 1.20e-04/9.54e-05, max scaled = 1.26e+00
# Element 4: residual (max/avg) = 1.52e-08/1.20e-08, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 4.10e-09/3.24e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.44e-09/2.73e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 6, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 25 ***
# Element 0: residual (max/avg) = 9.62e-10/7.62e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.70e-10/6.89e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.46e-10/5.12e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 3.04e-05/1.86e-05, max scaled = 1.63e+00
# Element 4: residual (max/avg) = 1.16e-08/9.17e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 4.01e-09/3.17e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.43e-09/2.72e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 9, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 26 ***
# Element 0: residual (max/avg) = 9.63e-10/7.63e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.73e-10/6.92e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.52e-10/5.17e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 1.45e-05/7.65e-06, max scaled = 1.89e+00
# Element 4: residual (max/avg) = 1.08e-08/8.59e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 3.98e-09/3.15e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.42e-09/2.71e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 12, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 27 ***
# Element 0: residual (max/avg) = 9.64e-10/7.64e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.75e-10/6.93e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.56e-10/5.20e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 8.60e-06/4.09e-06, max scaled = 2.10e+00
# 	Splitting at τ=-0.328125
# Element 4: residual (max/avg) = 1.04e-08/8.24e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 3.97e-09/3.14e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.42e-09/2.71e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 28 ***
# Element 0: residual (max/avg) = 9.72e-10/7.70e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 9.00e-10/7.13e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 7.07e-10/5.60e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 9.73e-10/7.71e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 2.12e-05/1.68e-05, max scaled = 1.26e+00
# Element 5: residual (max/avg) = 7.07e-09/5.60e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.79e-09/3.00e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.39e-09/2.68e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 6, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 29 ***
# Element 0: residual (max/avg) = 9.64e-10/7.63e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.74e-10/6.93e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.54e-10/5.18e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 7.79e-10/6.17e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 9.47e-06/5.80e-06, max scaled = 1.63e+00
# Element 5: residual (max/avg) = 1.06e-08/8.40e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.97e-09/3.15e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.42e-09/2.71e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 9, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 30 ***
# Element 0: residual (max/avg) = 9.68e-10/7.67e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.87e-10/7.02e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.80e-10/5.39e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 8.70e-10/6.89e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 5.27e-06/2.79e-06, max scaled = 1.89e+00
# Element 5: residual (max/avg) = 8.46e-09/6.70e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.88e-09/3.07e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.41e-09/2.70e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 12, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 31 ***
# Element 0: residual (max/avg) = 9.65e-10/7.64e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.78e-10/6.95e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.61e-10/5.24e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 8.01e-10/6.34e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 2.67e-06/1.27e-06, max scaled = 2.10e+00
# 	Splitting at τ=-0.3203125
# Element 5: residual (max/avg) = 9.88e-09/7.83e-09, max scaled = 1.26e+00
# 	Converged
# Element 6: residual (max/avg) = 3.94e-09/3.12e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.42e-09/2.71e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 3, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3203125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 32 ***
# Element 0: residual (max/avg) = 9.65e-10/7.64e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.78e-10/6.96e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.61e-10/5.24e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 7.98e-10/6.32e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 2.33e-09/1.85e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 2.17e-06/1.72e-06, max scaled = 1.26e+00
# Element 6: residual (max/avg) = 9.78e-09/7.75e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.94e-09/3.12e-09, max scaled = 1.26e+00
# 	Converged
# Element 8: residual (max/avg) = 3.42e-09/2.71e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 6, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3203125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 33 ***
# Element 0: residual (max/avg) = 9.66e-10/7.65e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.82e-10/6.99e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.69e-10/5.30e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 8.27e-10/6.55e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 2.23e-09/1.77e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 2.19e-06/1.34e-06, max scaled = 1.63e+00
# Element 6: residual (max/avg) = 9.23e-09/7.31e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.92e-09/3.10e-09, max scaled = 1.26e+00
# 	Converged
# Element 8: residual (max/avg) = 3.41e-09/2.70e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 9, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3203125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 34 ***
# Element 0: residual (max/avg) = 9.65e-10/7.65e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.79e-10/6.97e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.64e-10/5.26e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 8.10e-10/6.42e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 1.86e-09/1.47e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 1.60e-06/8.48e-07, max scaled = 1.89e+00
# Element 6: residual (max/avg) = 9.65e-09/7.64e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.93e-09/3.12e-09, max scaled = 1.26e+00
# 	Converged
# Element 8: residual (max/avg) = 3.42e-09/2.71e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 12, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3203125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]
#
# *** Iteration 35 ***
# Element 0: residual (max/avg) = 9.66e-10/7.65e-10, max scaled = 1.26e+00
# 	Converged
# Element 1: residual (max/avg) = 8.80e-10/6.97e-10, max scaled = 1.26e+00
# 	Converged
# Element 2: residual (max/avg) = 6.66e-10/5.28e-10, max scaled = 1.26e+00
# 	Converged
# Element 3: residual (max/avg) = 8.17e-10/6.47e-10, max scaled = 1.26e+00
# 	Converged
# Element 4: residual (max/avg) = 2.01e-09/1.59e-09, max scaled = 1.26e+00
# 	Converged
# Element 5: residual (max/avg) = 4.76e-07/2.26e-07, max scaled = 2.10e+00
# 	Converged
# Element 6: residual (max/avg) = 9.47e-09/7.50e-09, max scaled = 1.26e+00
# 	Converged
# Element 7: residual (max/avg) = 3.93e-09/3.11e-09, max scaled = 1.26e+00
# 	Converged
# Element 8: residual (max/avg) = 3.41e-09/2.70e-09, max scaled = 1.26e+00
# 	Converged
# New domain: [3, 3, 3, 3, 3, 12, 3, 3, 3], knots=[np.float64(-0.5), np.float64(-0.375), np.float64(-0.34375), np.float64(-0.328125), np.float64(-0.3203125), np.float64(-0.3125), np.float64(-0.25), np.float64(0.0)]

# %%
t_plt = np.linspace(sol.t0, sol.tf, 2000)
x_plt = sol.x(t_plt)
u_plt = sol.u(t_plt)

fig, ax = plt.subplots(3, 1, figsize=(7, 3), sharex=True)
ax[0].scatter(sol.tp, sol.xp[:, 0], c="k", s=8)
ax[0].plot(t_plt, x_plt[:, 0], c="k")
ax[0].legend()
ax[0].grid()
ax[0].set_ylabel(r"$h$")
ax[1].scatter(sol.tp, sol.xp[:, 1], c="k", s=8)
ax[1].plot(t_plt, x_plt[:, 1], c="k")
ax[1].legend()
ax[1].grid()
ax[1].set_ylabel(r"$v$")
ax[2].scatter(sol.tp[:-1], sol.up, c="k", s=8)
ax[2].plot(t_plt, u_plt, c="k")
ax[2].grid()
ax[2].set_ylabel(r"$u$")
ax[2].set_xlabel(r"$t$")
# ax[2].set_xlim([1.36, 1.45])

plt.show()
# Out:
# /var/folders/s6/pyplp64s6cg0fs1312qb3pnh0000gn/T/ipykernel_88487/3703850239.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[0].legend()
# /var/folders/s6/pyplp64s6cg0fs1312qb3pnh0000gn/T/ipykernel_88487/3703850239.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[1].legend()

# %%
# Analytic solution
h0, v0 = x0
tf_opt = (2 * v0) / 3 + 4 * np.sqrt(0.5 * v0**2 + 1.5 * h0) / 3
s_opt = 0.5 * tf_opt + v0 / 3  # Optimal switching time


def h1(t):
    return -0.75 * t**2 + v0 * t + h0


def v1(t):
    return -1.5 * t + v0


def h2(t):
    return 0.75 * t**2 + (v0 - 3 * s_opt) * t + 1.5 * s_opt**2 + h0


def v2(t):
    return 1.5 * t + v0 - 3 * s_opt


print(f"Optimal time: {tf_opt:.4f}")
print(f"Optimal switching time: {s_opt:.4f}")
# Out:
# Optimal time: 4.1641
# Optimal switching time: 1.4154
