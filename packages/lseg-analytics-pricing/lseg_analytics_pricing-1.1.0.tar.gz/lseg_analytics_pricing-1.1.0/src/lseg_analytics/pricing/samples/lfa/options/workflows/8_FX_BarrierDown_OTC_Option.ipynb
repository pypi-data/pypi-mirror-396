# %% [markdown]
# # FX Barrier Down OTC Options

# %% [markdown]
# This notebook demonstrates how to access and use the functinalities of **FX Options** which are part of our **QPS** module within LSEG Financial Analytics SDK.

# %% [markdown]
# ## Imports

# %%
from lseg_analytics.pricing.instruments.options import (
    value,
    OptionDefinition,
    OptionDefinitionInstrument,
    OptionPricingParameters,
    UnderlyingDefinition,
    ExerciseDefinition,
    ScheduleDefinition,
    BarrierDefinition
)

from lseg_analytics.pricing.common import AdjustableDate
from datetime import date
import json as js

# %% [markdown]
# ## Pricing an FX Barrier Down OTC Option

# %%
definition = OptionDefinition(
    underlying = UnderlyingDefinition(
        code="EURUSD",
        underlying_type="Fx"
    ),
    exercise= ExerciseDefinition(
        strike=1.01,
        schedule = ScheduleDefinition(
            end_date = AdjustableDate(
                date = date(2025, 3, 18)
            )
        )
    ),
    barrier_down= BarrierDefinition(
        barrier_mode="European",
        level=1.2,
        in_or_out="In"
    ),
    option_type="Call",
    notional_amount={
        "value": 1000000,
        "currency": "EUR"
    }
)

pricing_parameters=OptionPricingParameters(
    valuation_date=date(2024, 12, 18)
)

response = value(
    definitions=[OptionDefinitionInstrument(definition=definition)],
    pricing_preferences=pricing_parameters
)

print(js.dumps(response.as_dict(), indent=4))
# Out:
# {
#     "definitions": [
#         {
#             "definition": {
#                 "underlying": {
#                     "underlyingType": "Fx",
#                     "code": "EURUSD"
#                 },
#                 "exercise": {
#                     "strike": 1.01,
#                     "schedule": {
#                         "endDate": {
#                             "dateType": "AdjustableDate",
#                             "date": "2025-03-18"
#                         }
#                     }
#                 },
#                 "optionType": "Call",
#                 "notionalAmount": {
#                     "value": 1000000.0,
#                     "currency": "EUR"
#                 },
#                 "barrierDown": {
#                     "barrierMode": "European",
#                     "inOrOut": "In",
#                     "level": 1.2
#                 }
#             }
#         }
#     ],
#     "pricingPreferences": {
#         "valuationDate": "2024-12-18"
#     },
#     "analytics": [
#         {
#             "description": {
#                 "instrumentDescription": "EURUSD Barrier CALL Option 1.01 2025-03-18"
#             },
#             "valuation": {
#                 "volatility": {
#                     "value": 0.0,
#                     "unit": "Percentage"
#                 },
#                 "marketValue": {
#                     "value": 35339.8645148053,
#                     "dealCurrency": {
#                         "value": 35339.8645148053,
#                         "currency": "EUR"
#                     },
#                     "domesticCurrency": {
#                         "value": 36585.5947389522,
#                         "currency": "USD"
#                     },
#                     "foreignCurrency": {
#                         "value": 35339.8645148053,
#                         "currency": "EUR"
#                     }
#                 },
#                 "forwardPremium": {
#                     "value": 3.55947532876183,
#                     "unit": "Percentage"
#                 },
#                 "forwardMarketValue": {
#                     "value": 3.55947532876183,
#                     "dealCurrency": {
#                         "value": 35594.7532876183,
#                         "currency": "EUR"
#                     },
#                     "domesticCurrency": {
#                         "value": 36997.7926718863,
#                         "currency": "USD"
#                     },
#                     "foreignCurrency": {
#                         "value": 35594.7532876183,
#                         "currency": "EUR"
#                     }
#                 },
#                 "fxSpot": 1.03525,
#                 "fxOutright": 1.039417,
#                 "fxSwap": 41.6700000000003,
#                 "domesticDepositRate": {
#                     "value": 4.5066692054649,
#                     "unit": "Percentage"
#                 },
#                 "foreignDepositRate": {
#                     "value": 2.88500000000003,
#                     "unit": "Percentage"
#                 }
#             },
#             "risk": {
#                 "delta": {
#                     "value": 0.738791836092381,
#                     "percent": 73.8791836092381,
#                     "dealCurrency": {
#                         "value": 738791.836092381,
#                         "currency": "EUR"
#                     },
#                     "domesticCurrency": {
#                         "value": -764834.248314637,
#                         "currency": "USD"
#                     },
#                     "foreignCurrency": {
#                         "value": 738791.836092381,
#                         "currency": "EUR"
#                     }
#                 },
#                 "gamma": {
#                     "value": 0.06971421695709461,
#                     "percent": 6.971421695709461,
#                     "dealCurrency": {
#                         "value": 69714.2169570946,
#                         "currency": "EUR"
#                     },
#                     "domesticCurrency": {
#                         "value": 72171.6431048322,
#                         "currency": "USD"
#                     },
#                     "foreignCurrency": {
#                         "value": 69714.2169570946,
#                         "currency": "EUR"
#                     }
#                 },
#                 "rho": {
#                     "value": 0.0017147972690283201,
#                     "percent": 0.171479726902832,
#                     "dealCurrency": {
#                         "value": 1714.79726902832,
#                         "currency": "EUR"
#                     },
#                     "domesticCurrency": {
#                         "value": 1775.24387276157,
#                         "currency": "USD"
#                     },
#                     "foreignCurrency": {
#                         "value": 1714.79726902832,
#                         "currency": "EUR"
#                     }
#                 },
#                 "theta": {
#                     "value": -9.946689493335541e-05,
#                     "percent": -0.00994668949333554,
#                     "dealCurrency": {
#                         "value": -99.4668949333554,
#                         "currency": "EUR"
#                     },
#                     "domesticCurrency": {
#                         "value": -102.973102979756,
#                         "currency": "USD"
#                     },
#                     "foreignCurrency": {
#                         "value": -99.4668949333554,
#                         "currency": "EUR"
#                     }
#                 },
#                 "vega": {
#                     "value": 0.0016082921564422002,
#                     "percent": 0.16082921564422004,
#                     "dealCurrency": {
#                         "value": 1608.2921564422,
#                         "currency": "EUR"
#                     },
#                     "domesticCurrency": {
#                         "value": 1664.98445495679,
#                         "currency": "USD"
#                     },
#                     "foreignCurrency": {
#                         "value": 1608.2921564422,
#                         "currency": "EUR"
#                     }
#                 }
#             }
#         }
#     ]
# }

# %%
valuation = response.analytics[0].valuation

print(js.dumps(valuation.as_dict(), indent=4))
# Out:
# {
#     "volatility": {
#         "value": 0.0,
#         "unit": "Percentage"
#     },
#     "marketValue": {
#         "value": 35339.8645148053,
#         "dealCurrency": {
#             "value": 35339.8645148053,
#             "currency": "EUR"
#         },
#         "domesticCurrency": {
#             "value": 36585.5947389522,
#             "currency": "USD"
#         },
#         "foreignCurrency": {
#             "value": 35339.8645148053,
#             "currency": "EUR"
#         }
#     },
#     "forwardPremium": {
#         "value": 3.55947532876183,
#         "unit": "Percentage"
#     },
#     "forwardMarketValue": {
#         "value": 3.55947532876183,
#         "dealCurrency": {
#             "value": 35594.7532876183,
#             "currency": "EUR"
#         },
#         "domesticCurrency": {
#             "value": 36997.7926718863,
#             "currency": "USD"
#         },
#         "foreignCurrency": {
#             "value": 35594.7532876183,
#             "currency": "EUR"
#         }
#     },
#     "fxSpot": 1.03525,
#     "fxOutright": 1.039417,
#     "fxSwap": 41.6700000000003,
#     "domesticDepositRate": {
#         "value": 4.5066692054649,
#         "unit": "Percentage"
#     },
#     "foreignDepositRate": {
#         "value": 2.88500000000003,
#         "unit": "Percentage"
#     }
# }
