# %% [markdown]
# # Multi-Scenario Scenario Analysis

# %% [markdown]
# Scenario Analysis (SA) functionality enables users to subdue their instrument(s) to a variety of settable environments to observe their potential behavior or influence.
#
# Users can enforce changes to situational properties or event horizon itself, or both to simulate possible outcomes.
#
# Mandatory information to provide is:
# - ID(s) of the instrument(s)
# - Settlement level
# - Name of existing (saved) scenario
# - Curve type to be used for underlying calculations
# - Pricing date
# - Horizon PY method

# %% [markdown]
# ## Import list

# %%
import json as js

from lseg_analytics.pricing.yield_book_rest import (
        request_scenario_calculation_sync,
        CurveTypeAndCurrency,
        ScenarioCalcGlobalSettings,
        Scenario,
        ScenarioDefinition,
        SystemScenario,
        ScenarioCalcInput,
        SettlementInfo,
        HorizonInfo,
)

# %% [markdown]
# ## Multi-scenario setup

# %% [markdown]
# User can define a large number of scenarios which will be used on provided instrument(s) as follows:

# %%
global_settings = ScenarioCalcGlobalSettings(
            pricing_date="2025-01-01",
        )

scenario_1 = Scenario(
            scenario_id="ScenID1",
            definition=ScenarioDefinition(
                system_scenario=SystemScenario(name="BEARFLAT100")
            ),
        )

scenario_2 = Scenario(
            scenario_id="ScenID2",
            definition=ScenarioDefinition(
                system_scenario=SystemScenario(name="BULLFLAT50")
            ),
        )

scenario_3 = Scenario(
            scenario_id="ScenID3",
            definition=ScenarioDefinition(
                system_scenario=SystemScenario(name="YR20PLUS25")
            ),
        )

scenario_4 = Scenario(
            scenario_id="ScenID4",
            definition=ScenarioDefinition(
                system_scenario=SystemScenario(name="PC3MOCOMP1DOWN")
            ),
        )

scenario_5 = Scenario(
            scenario_id="ScenID5",
            definition=ScenarioDefinition(
                system_scenario=SystemScenario(name="IRRBB26STEEP")
            ),
        )

# Combining Scenarios and Input instruments and parameters
input_1 = ScenarioCalcInput(
            identifier="US742718AV11",
            id_type="ISIN",
            curve=CurveTypeAndCurrency(
                curve_type="GVT",
                currency="USD",
            ),
            settlement_info=SettlementInfo(
                level="100",
            ),
            horizon_info=[
                HorizonInfo(
                    scenario_id="ScenID1",
                    level="100",
                ),                
                HorizonInfo(
                    scenario_id="ScenID2",
                    level="90",
                ),                
                HorizonInfo(
                    scenario_id="ScenID4",
                    level="95",
                ),
                HorizonInfo(
                    scenario_id="ScenID5",
                    level="105",
                )
            ],
            horizon_py_method="OAS",
        )

input_2 = ScenarioCalcInput(
            identifier="91282CLF6",
            id_type="CUSIP",
            curve=CurveTypeAndCurrency(
                curve_type="GVT",
                currency="USD",
            ),
            settlement_info=SettlementInfo(
                level="99",
            ),
            horizon_info=[
                HorizonInfo(
                    scenario_id="ScenID2",
                    level="98.15",
                ),                
                HorizonInfo(
                    scenario_id="ScenID3",
                    level="91.47",
                ),                
                HorizonInfo(
                    scenario_id="ScenID4",
                    level="95.54",
                ),
                HorizonInfo(
                    scenario_id="ScenID5",
                    level="101.13",
                )
            ],
            horizon_py_method="OAS",
        )

# %% [markdown]
# ## Scenario Analysis

# %%
# Execute Post sync request with prepared inputs
sa_sync_post_response = request_scenario_calculation_sync(
                            global_settings=global_settings,
                            scenarios=[scenario_1, scenario_2, scenario_3, scenario_4, scenario_5],
                            input=[input_1, input_2],
                        )

print(js.dumps(sa_sync_post_response, indent=4))
# Out:
# {
#     "meta": {
#         "status": "DONE",
#         "requestId": "R-150631",
#         "timeStamp": "2025-12-03T07:44:25Z",
#         "responseType": "SCENARIO_CALC",
#         "resultsStatus": "ALL"
#     },
#     "results": [
#         {
#             "isin": "US742718AV11",
#             "cusip": "742718AV1",
#             "ticker": "PG",
#             "scenario": {
#                 "horizon": [
#                     {
#                         "oas": 100.0,
#                         "wal": 4.8139,
#                         "price": 104.89765,
#                         "yield": 6.7865,
#                         "balance": 1.0,
#                         "pylevel": "100.000000",
#                         "duration": 3.9209,
#                         "fullPrice": 106.386538,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID1",
#                         "spreadDV01": 0.0,
#                         "volatility": 16.0,
#                         "actualPrice": 104.898,
#                         "grossSpread": 99.9335,
#                         "horizonDays": 0,
#                         "marketValue": 106.386538,
#                         "optionValue": 0.0,
#                         "totalReturn": 4.8257988,
#                         "dollarReturn": 4.89764958,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 99.9335,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.488889,
#                         "actualFullPrice": 106.387,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": 4.8257988,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 5.145556,
#                         "yieldCurveMargin": 100.0,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.489
#                     },
#                     {
#                         "oas": 90.0,
#                         "wal": 4.8139,
#                         "price": 113.333687,
#                         "yield": 4.8577,
#                         "balance": 1.0,
#                         "pylevel": "90.000000",
#                         "duration": 3.9917,
#                         "fullPrice": 114.822576,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID2",
#                         "spreadDV01": 0.0,
#                         "volatility": 16.0,
#                         "actualPrice": 113.334,
#                         "grossSpread": 90.0423,
#                         "horizonDays": 0,
#                         "marketValue": 114.822576,
#                         "optionValue": 0.0,
#                         "totalReturn": 13.13807556,
#                         "dollarReturn": 13.3336869,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 90.0423,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.488889,
#                         "actualFullPrice": 114.823,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": 13.13807556,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 4.289356,
#                         "yieldCurveMargin": 90.0,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.489
#                     },
#                     {
#                         "oas": 95.0,
#                         "wal": 4.8139,
#                         "price": 113.583812,
#                         "yield": 4.8032,
#                         "balance": 1.0,
#                         "pylevel": "95.000000",
#                         "duration": 3.9937,
#                         "fullPrice": 115.072701,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID4",
#                         "spreadDV01": 0.0,
#                         "volatility": 16.0,
#                         "actualPrice": 113.584,
#                         "grossSpread": 94.5198,
#                         "horizonDays": 0,
#                         "marketValue": 115.072701,
#                         "optionValue": 0.0,
#                         "totalReturn": 13.38453169,
#                         "dollarReturn": 13.58381249,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 94.5198,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.488889,
#                         "actualFullPrice": 115.073,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": 13.38453169,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 4.121356,
#                         "yieldCurveMargin": 95.0,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.489
#                     },
#                     {
#                         "oas": 105.0,
#                         "wal": 4.8139,
#                         "price": 107.307506,
#                         "yield": 6.2168,
#                         "balance": 1.0,
#                         "pylevel": "105.000000",
#                         "duration": 3.9418,
#                         "fullPrice": 108.796394,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID5",
#                         "spreadDV01": 0.0,
#                         "volatility": 16.0,
#                         "actualPrice": 107.308,
#                         "grossSpread": 100.4387,
#                         "horizonDays": 0,
#                         "marketValue": 108.796394,
#                         "optionValue": 0.0,
#                         "totalReturn": 7.20030114,
#                         "dollarReturn": 7.30750562,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 100.4387,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.488889,
#                         "actualFullPrice": 108.796,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": 7.20030114,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 2.620756,
#                         "yieldCurveMargin": 105.0,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.489
#                     }
#                 ],
#                 "settlement": {
#                     "oas": 361.951,
#                     "psa": 0.0,
#                     "wal": 4.8139,
#                     "price": 100.0,
#                     "yield": 7.9953,
#                     "fullPrice": 101.488889,
#                     "volatility": 13.0,
#                     "grossSpread": 361.2649,
#                     "optionValue": 0.0,
#                     "pricingDate": "2024-12-31",
#                     "forwardYield": 0.0,
#                     "staticSpread": 0.0,
#                     "effectiveDV01": 0.039405887,
#                     "nominalSpread": 0.0,
#                     "settlementDate": "2025-01-03",
#                     "accruedInterest": 1.488889,
#                     "reinvestmentRate": 4.329956,
#                     "yieldCurveMargin": 0.0,
#                     "effectiveDuration": 3.8828,
#                     "effectiveConvexity": 0.1873
#                 }
#             },
#             "returnCode": 0,
#             "securityID": "742718AV",
#             "description": "PROCTER & GAMBLE CO",
#             "maturityDate": "2029-10-26",
#             "securityType": "BOND",
#             "currentCoupon": 8.0
#         },
#         {
#             "isin": "US91282CLF67",
#             "cusip": "91282CLF6",
#             "ticker": "US",
#             "scenario": {
#                 "horizon": [
#                     {
#                         "oas": 98.15,
#                         "wal": 9.6167,
#                         "price": 91.414419,
#                         "yield": 5.0104,
#                         "balance": 1.0,
#                         "pylevel": "98.150002",
#                         "duration": 7.7148,
#                         "fullPrice": 92.899134,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID2",
#                         "spreadDV01": 0.0,
#                         "actualPrice": 91.414,
#                         "grossSpread": 98.139,
#                         "horizonDays": 0,
#                         "marketValue": 92.899134,
#                         "optionValue": 0.0,
#                         "totalReturn": -7.54898981,
#                         "dollarReturn": -7.58558087,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 98.139,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.484715,
#                         "actualFullPrice": 92.899,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": -7.54898981,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 4.289356,
#                         "yieldCurveMargin": 98.15,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.485
#                     },
#                     {
#                         "oas": 91.47,
#                         "wal": 9.6167,
#                         "price": 88.10078,
#                         "yield": 5.4829,
#                         "balance": 1.0,
#                         "pylevel": "91.470001",
#                         "duration": 7.658,
#                         "fullPrice": 89.585495,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID3",
#                         "spreadDV01": 0.0,
#                         "actualPrice": 88.101,
#                         "grossSpread": 91.7103,
#                         "horizonDays": 0,
#                         "marketValue": 89.585495,
#                         "optionValue": 0.0,
#                         "totalReturn": -10.84664481,
#                         "dollarReturn": -10.89922008,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 91.7103,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.484715,
#                         "actualFullPrice": 89.585,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": -10.84664481,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 4.329956,
#                         "yieldCurveMargin": 91.47,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.485
#                     },
#                     {
#                         "oas": 95.54,
#                         "wal": 9.6167,
#                         "price": 91.311282,
#                         "yield": 5.0248,
#                         "balance": 1.0,
#                         "pylevel": "95.540001",
#                         "duration": 7.713,
#                         "fullPrice": 92.795996,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID4",
#                         "spreadDV01": 0.0,
#                         "actualPrice": 91.311,
#                         "grossSpread": 95.533,
#                         "horizonDays": 0,
#                         "marketValue": 92.795996,
#                         "optionValue": 0.0,
#                         "totalReturn": -7.65162985,
#                         "dollarReturn": -7.68871842,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 95.533,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.484715,
#                         "actualFullPrice": 92.796,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": -7.65162985,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 4.121356,
#                         "yieldCurveMargin": 95.54,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.485
#                     },
#                     {
#                         "oas": 101.13,
#                         "wal": 9.6167,
#                         "price": 76.559834,
#                         "yield": 7.3104,
#                         "balance": 1.0,
#                         "pylevel": "101.129997",
#                         "duration": 7.4347,
#                         "fullPrice": 78.044549,
#                         "returnCode": 0,
#                         "scenarioID": "ScenID5",
#                         "spreadDV01": 0.0,
#                         "actualPrice": 76.56,
#                         "grossSpread": 107.9105,
#                         "horizonDays": 0,
#                         "marketValue": 78.044549,
#                         "optionValue": 0.0,
#                         "totalReturn": -22.33191984,
#                         "dollarReturn": -22.44016593,
#                         "convexityCost": 0.0,
#                         "nominalSpread": 107.9105,
#                         "effectiveYield": 0.0,
#                         "interestReturn": 0.0,
#                         "settlementDate": "2025-01-03",
#                         "spreadDuration": 0.0,
#                         "accruedInterest": 1.484715,
#                         "actualFullPrice": 78.045,
#                         "horizonPYMethod": "OAS",
#                         "interestPayment": 0.0,
#                         "principalReturn": -22.33191984,
#                         "underlyingPrice": 0.0,
#                         "principalPayment": 0.0,
#                         "reinvestmentRate": 2.620756,
#                         "yieldCurveMargin": 101.13,
#                         "effectiveCallDate": "0",
#                         "reinvestmentAmount": 0.0,
#                         "actualAccruedInterest": 1.485
#                     }
#                 ],
#                 "settlement": {
#                     "oas": -56.9129,
#                     "psa": 0.0,
#                     "wal": 9.6167,
#                     "price": 99.0,
#                     "yield": 4.0009,
#                     "fullPrice": 100.484715,
#                     "volatility": 13.0,
#                     "grossSpread": -56.4988,
#                     "optionValue": 0.0,
#                     "pricingDate": "2024-12-31",
#                     "forwardYield": 0.0,
#                     "staticSpread": 0.0,
#                     "effectiveDV01": 0.07914189,
#                     "nominalSpread": 0.0,
#                     "settlementDate": "2025-01-03",
#                     "accruedInterest": 1.484715,
#                     "reinvestmentRate": 4.329956,
#                     "yieldCurveMargin": 0.0,
#                     "effectiveDuration": 7.876,
#                     "effectiveConvexity": 0.7379
#                 }
#             },
#             "returnCode": 0,
#             "securityID": "91282CLF",
#             "description": "US TREASURY",
#             "maturityDate": "2034-08-15",
#             "securityType": "BOND",
#             "currentCoupon": 3.875
#         }
#     ]
# }
