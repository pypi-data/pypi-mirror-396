# %% [markdown]
# # Double Barrier OTC Options

# %% [markdown]
# This notebook demonstrates how to access and use the functinalities of **Equity Options** which are part of our **QPS** module within LSEG Financial Analytics SDK.

# %% [markdown]
# ## Imports

# %% [markdown]
# This notebook uses the external library **pandas**; please ensure it is installed in your Python environment (e.g. 'pip install pandas') before running the code.

# %%
from lseg_analytics.pricing.instruments.options import (
    value,
    OptionDefinition,
    OptionDefinitionInstrument,
    OptionPricingParameters,
    UnderlyingDefinition,
    ExerciseDefinition,
    ScheduleDefinition,
    BarrierDefinition
)

from lseg_analytics.pricing.common import AdjustableDate
from datetime import date
import pandas as pd
import json as js

# %% [markdown]
# ## Pricing a Double Barrier OTC Option

# %%
definition = OptionDefinition(
    underlying = UnderlyingDefinition(
        code="ASML.AS",
        underlying_type="Equity"
    ),
    exercise = ExerciseDefinition(
        strike=240,
        exercise_style="European",
        schedule = ScheduleDefinition(
            end_date = AdjustableDate(
                date = date(2025, 8, 13)
            )
        )
    ),
    barrier_up= BarrierDefinition(
        barrier_mode="European",
        level=250,
        in_or_out="Out"
    ),
    barrier_down= BarrierDefinition(
        barrier_mode="European",
        level=220,
        in_or_out="Out"
    ),
    option_type="Call"
)

pricing_parameters=OptionPricingParameters(
    valuation_date=date(2024, 12, 18)
)

response = value(
    definitions=[OptionDefinitionInstrument(definition=definition)],
    pricing_preferences=pricing_parameters
)

print(js.dumps(response.as_dict(), indent=4))
# Out:
# {
#     "definitions": [
#         {
#             "definition": {
#                 "underlying": {
#                     "underlyingType": "Equity",
#                     "code": "ASML.AS"
#                 },
#                 "exercise": {
#                     "strike": 240.0,
#                     "schedule": {
#                         "endDate": {
#                             "dateType": "AdjustableDate",
#                             "date": "2025-08-13"
#                         }
#                     },
#                     "exerciseStyle": "European"
#                 },
#                 "optionType": "Call",
#                 "barrierUp": {
#                     "barrierMode": "European",
#                     "inOrOut": "Out",
#                     "level": 250.0
#                 },
#                 "barrierDown": {
#                     "barrierMode": "European",
#                     "inOrOut": "Out",
#                     "level": 220.0
#                 }
#             }
#         }
#     ],
#     "pricingPreferences": {
#         "valuationDate": "2024-12-18"
#     },
#     "analytics": [
#         {
#             "description": {
#                 "instrumentCode": "",
#                 "underlyingRic": "ASML.AS",
#                 "instrumentDescription": "Barrier_EURO_ASML.AS"
#             },
#             "valuation": {
#                 "volatility": {
#                     "value": 51.7541577928273,
#                     "unit": "Percentage"
#                 },
#                 "marketValue": {
#                     "value": 477.706936177938,
#                     "dealCurrency": {
#                         "value": 477.706936177938,
#                         "currency": "EUR"
#                     }
#                 },
#                 "totalMarketValue": {
#                     "value": 477.706936177938,
#                     "dealCurrency": {
#                         "value": 477.706936177938,
#                         "currency": "EUR"
#                     }
#                 },
#                 "intrinsicValue": {
#                     "value": 477.3,
#                     "dealCurrency": {
#                         "value": 477.3,
#                         "currency": "EUR"
#                     }
#                 },
#                 "timeValue": {
#                     "value": 0.40693617793761,
#                     "dealCurrency": {
#                         "value": 0.40693617793761,
#                         "currency": "EUR"
#                     }
#                 },
#                 "premiumOverCash": {
#                     "value": 0.0005673165731738599,
#                     "percent": 0.056731657317386,
#                     "dealCurrency": {
#                         "value": 0.40693617793761,
#                         "currency": "EUR"
#                     }
#                 },
#                 "moneyness": {
#                     "value": 298.875,
#                     "unit": "Percentage"
#                 },
#                 "annualizedYield": {
#                     "value": 0.000866403971583509,
#                     "unit": "Absolute"
#                 }
#             },
#             "risk": {
#                 "hedgeRatio": -1.00771287735766,
#                 "leverage": 1.4900556044952,
#                 "delta": {
#                     "value": 0.992346155803944,
#                     "percent": 99.2346155803944,
#                     "dealCurrency": {
#                         "value": 0.992346155803944,
#                         "currency": "EUR"
#                     }
#                 },
#                 "gamma": {
#                     "value": 2.23299534992099e-05,
#                     "percent": 0.00223299534992099,
#                     "dealCurrency": {
#                         "value": 2.23299534992099e-05,
#                         "currency": "EUR"
#                     }
#                 },
#                 "rho": {
#                     "value": 1.52647447657728,
#                     "percent": 152.647447657728,
#                     "dealCurrency": {
#                         "value": 1.52647447657728,
#                         "currency": "EUR"
#                     }
#                 },
#                 "theta": {
#                     "value": -0.00481557356562234,
#                     "percent": -0.481557356562234,
#                     "dealCurrency": {
#                         "value": -0.00481557356562234,
#                         "currency": "EUR"
#                     }
#                 },
#                 "vega": {
#                     "value": 0.0387906122114146,
#                     "percent": 3.8790612211414603,
#                     "dealCurrency": {
#                         "value": 0.0387906122114146,
#                         "currency": "EUR"
#                     }
#                 }
#             }
#         }
#     ]
# }

# %%
valuation = response.analytics[0].valuation

import pandas as pd

def flatten(data):
    rows = []

    for key, section in data.items():
        row = {"metric": key}

        # Start with raw values
        value = section.get("value")
        unit = section.get("unit")
        percent = section.get("percent")

        # Handle dealCurrency override
        dc = section.get("dealCurrency")
        if dc is not None:
            value = getattr(dc, "value", value)
            unit = getattr(dc, "currency", unit)

        # Round and assign
        if value is not None:
            row["value"] = round(value, 3)
        if unit is not None:
            row["unit"] = unit
        if percent is not None:
            row["percent"] = round(percent, 3)

        rows.append(row)

    return pd.DataFrame(rows).set_index("metric")

flatten(valuation)
# Out:
#                     value        unit  percent
# metric
# volatility         51.754  Percentage      NaN
# marketValue       477.707         EUR      NaN
# totalMarketValue  477.707         EUR      NaN
# intrinsicValue    477.300         EUR      NaN
# timeValue           0.407         EUR      NaN
# premiumOverCash     0.407         EUR    0.057
# moneyness         298.875  Percentage      NaN
# annualizedYield     0.001    Absolute      NaN
