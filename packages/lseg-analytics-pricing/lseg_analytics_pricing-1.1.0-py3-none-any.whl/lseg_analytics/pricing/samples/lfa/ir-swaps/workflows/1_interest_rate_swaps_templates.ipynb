# %% [markdown]
# # Interest Rate Swaps Templates

# %% [markdown]
# This notebook demonstrates how to access and use the functionalities of swap templates which are part of our 'lseg_analytics.pricing.templates.instrument_templates' module within LSEG Financial Analytics SDK.

# %% [markdown]
# ## Imports

# %% [markdown]
# This notebook uses external libraries **pandas, IPython**; please ensure they are installed in your Python environment (e.g. 'pip install pandas') before running the code.
#
# The following modules will be required in this notebook:

# %%
import pandas as pd
import json
from lseg_analytics.pricing.templates.instrument_templates import search, load
from lseg_analytics.pricing.common import SortingOrderEnum
from IPython.display import display

# %% [markdown]
# ## Utility methods

# %%
def extract_tag_key(tag):
    return tag.split(":")[0] if ":" in tag else tag

def list_unique_tags(all_swaps):
    unique_tags = set()
    for item in all_swaps:
        tags = item.get("description", {}).get("tags", [])
        for tag in tags:
            key = extract_tag_key(tag)
            unique_tags.add(key)
    return unique_tags

def display_templates(templates):
    unique_tag_keys = list(list_unique_tags(templates))

    rows = []
    for item in templates:
        row = {
            "Space": item.get("location", {}).get("space", ""),
            "Id": item.get("id", ""),
            "Name": item.get("location", {}).get("name", ""),
            "Summary": item.get("description", {}).get("summary", ""),
        }
        tags = item.get("description", {}).get("tags", [])
        tag_dict = {extract_tag_key(tag): tag for tag in tags}
        for key in unique_tag_keys:
            tag_val = tag_dict.get(key, None)
            if tag_val is not None and ":" in tag_val:
                row[key] = tag_val.split(":", 1)[1]
            else:
                row[key] = tag_val
        rows.append(row)

    display(pd.DataFrame(rows))

# %% [markdown]
# ## Searching for LSEG swap templates

# %% [markdown]
# Retrieve 3 swap templates from the 'LSEG' space, sorted by name in descending order.

# %%
swap_templates = search(item_per_page= 3, spaces=["LSEG"], space_name_sort_order = SortingOrderEnum.DESC)

display_templates(swap_templates)
# Out:
#   Space                                    Id        Name  \
# 0  LSEG  64fd0413-af5b-4acc-9640-fef158e2318a  ZARCBS_ZAR
# 1  LSEG  2f8fade9-bd91-4d6d-84da-07bb68d2defb  ZARCBS_USD
# 2  LSEG  ed4e7a46-62f4-4ce3-8da1-f21565cba75a      ZARCBS
#
#                                              Summary         index template  \
# 0  US dollar 3-Month Libor vs South african 3-Mon...  ZAR_JIBAR_3M   ZARCBS
# 1  US dollar 3-Month Libor vs South african 3-Mon...  USD_LIBOR_3M   ZARCBS
# 2  US dollar 3-Month Libor vs South african 3-Mon...  USD_LIBOR_3M     None
#
#       instrumentType currency legId
# 0    InterestRateLeg      ZAR   ZAR
# 1    InterestRateLeg      USD   USD
# 2  CurrencyBasisSwap      USD  None

# %% [markdown]
# Retrieve 5 vanilla interest rate swap templates in US Dollar (USD) from the LSEG space.

# %%
swap_templates = search(tags=["instrumentType:VanillaSwap", "currency:USD"], spaces=["LSEG"])

display_templates(swap_templates)
# Out:
#    Space                                    Id       Name  \
# 0   LSEG  b741203d-d1a9-4e66-b6d1-14b0fe914f0e   OIS_FFER
# 1   LSEG  a839a456-3ea5-4e8d-bc2e-a91e01ec876a   OIS_SOFR
# 2   LSEG  5fab064d-a590-475b-952d-454be58b05e4   USD_AB6L
# 3   LSEG  9bff16d2-962c-4ae2-9b5f-3845ef877746  USD_AM12L
# 4   LSEG  1a45ba17-addf-4f80-a2a3-a07d087248c1   USD_AM1L
# 5   LSEG  4ac28867-4d2e-4383-a524-c23add76d051   USD_AM3L
# 6   LSEG  ca9bd81c-0fd5-4469-8c2c-595de76fdfda   USD_AM6L
# 7   LSEG  4a76dd80-b63f-4801-9970-ce7f2b53b8ec  USD_SB12L
# 8   LSEG  f60cc703-99d9-4a26-8175-8059f8c3a0ca   USD_SB1L
# 9   LSEG  ed4d1b77-a86b-45b3-95b6-60181e917ecb   USD_SB3L
# 10  LSEG  808f04a8-cb52-4ac5-8b68-1b509f514304   USD_SB6L
# 11  LSEG  c09803aa-e8d0-48e5-a7d7-14c171b705f2     USDOIS
# 12  LSEG  aed0e73c-6c81-40a5-a7e5-1ff4bd78ed45   USDSROIS
#
#                                               Summary         index currency  \
# 0                      Overnight Indexed Swap US FFER   USD_FFER_ON      USD
# 1                           Overnight Index Swap SOFR   USD_SOFR_ON      USD
# 2         American Annual Bond Basis vs 6-Month Libor  USD_LIBOR_6M      USD
# 3      American Annual Money Market vs 12-Month Libor  USD_LIBOR_1Y      USD
# 4       American Annual Money Market vs 1-Month Libor  USD_LIBOR_1M      USD
# 5       American Annual Money Market vs 3-Month Libor  USD_LIBOR_3M      USD
# 6       American Annual Money Market vs 6-Month Libor  USD_LIBOR_6M      USD
# 7   American Semi-Annual Bond Basis vs 12-Month Libor  USD_LIBOR_1Y      USD
# 8    American Semi-Annual Bond Basis vs 1-Month Libor  USD_LIBOR_1M      USD
# 9    American Semi-Annual Bond Basis vs 3-Month Libor  USD_LIBOR_3M      USD
# 10   American Semi-Annual Bond Basis vs 6-Month Libor  USD_LIBOR_6M      USD
# 11                          Overnight Index Swap SOFR   USD_SOFR_ON      USD
# 12                          Overnight Index Swap SOFR   USD_SOFR_ON      USD
#
#    instrumentType
# 0     VanillaSwap
# 1     VanillaSwap
# 2     VanillaSwap
# 3     VanillaSwap
# 4     VanillaSwap
# 5     VanillaSwap
# 6     VanillaSwap
# 7     VanillaSwap
# 8     VanillaSwap
# 9     VanillaSwap
# 10    VanillaSwap
# 11    VanillaSwap
# 12    VanillaSwap

# %% [markdown]
# Access the swap template identified by the index 'USD_SOFR_ON'.

# %%
swap_templates = search(tags=["instrumentType:VanillaSwap", "currency:USD", "index:USD_SOFR_ON"],
                        spaces=["LSEG"],
                        item_per_page= 1)

display_templates(swap_templates)
# Out:
#   Space                                    Id      Name  \
# 0  LSEG  a839a456-3ea5-4e8d-bc2e-a91e01ec876a  OIS_SOFR
#
#                      Summary        index currency instrumentType
# 0  Overnight Index Swap SOFR  USD_SOFR_ON      USD    VanillaSwap

# %% [markdown]
# ## Loading a specific swap template

# %% [markdown]
# Load an LSEG/OIS_SOFR template using resource ID.

# %%
sofr_swap = load(resource_id="LSEG/OIS_SOFR")

print(json.dumps(sofr_swap.definition.as_dict(), indent=4))
# Out:
# {
#     "instrumentType": "VanillaSwap",
#     "template": {
#         "firstLeg": {
#             "rate": {
#                 "interestRateType": "FixedRate",
#                 "rate": {
#                     "value": 0.0,
#                     "unit": "Percentage"
#                 }
#             },
#             "interestPeriods": {
#                 "startDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "0D",
#                     "referenceDate": "SpotDate"
#                 },
#                 "endDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "10Y",
#                     "referenceDate": "StartDate"
#                 },
#                 "frequency": "Annual",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "rollConvention": "Same"
#             },
#             "paymentOffset": {
#                 "tenor": "2D",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "referenceDate": "PeriodEndDate",
#                 "direction": "Forward"
#             },
#             "couponDayCount": "Dcb_Actual_360",
#             "accrualDayCount": "Dcb_Actual_360",
#             "principal": {
#                 "currency": "USD",
#                 "amount": 10000000.0,
#                 "initialPrincipalExchange": false,
#                 "finalPrincipalExchange": false,
#                 "interimPrincipalExchange": false,
#                 "repaymentCurrency": "USD"
#             },
#             "payer": "Party1",
#             "receiver": "Party2"
#         },
#         "secondLeg": {
#             "rate": {
#                 "interestRateType": "FloatingRate",
#                 "index": "LSEG/USD_SOFR_ON_FRBNY",
#                 "spreadSchedule": [
#                     {
#                         "rate": {
#                             "value": 0.0,
#                             "unit": "BasisPoint"
#                         }
#                     }
#                 ],
#                 "resetDates": {
#                     "offset": {
#                         "tenor": "0D",
#                         "businessDayAdjustment": {
#                             "calendars": [],
#                             "convention": "ModifiedFollowing"
#                         },
#                         "referenceDate": "PeriodEndDate",
#                         "direction": "Backward"
#                     }
#                 },
#                 "leverage": 1.0
#             },
#             "interestPeriods": {
#                 "startDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "0D",
#                     "referenceDate": "SpotDate"
#                 },
#                 "endDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "10Y",
#                     "referenceDate": "StartDate"
#                 },
#                 "frequency": "Annual",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "rollConvention": "Same"
#             },
#             "paymentOffset": {
#                 "tenor": "2D",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "referenceDate": "PeriodEndDate",
#                 "direction": "Forward"
#             },
#             "couponDayCount": "Dcb_Actual_360",
#             "accrualDayCount": "Dcb_Actual_360",
#             "principal": {
#                 "currency": "USD",
#                 "amount": 10000000.0,
#                 "initialPrincipalExchange": false,
#                 "finalPrincipalExchange": false,
#                 "interimPrincipalExchange": false,
#                 "repaymentCurrency": "USD"
#             },
#             "payer": "Party2",
#             "receiver": "Party1"
#         }
#     }
# }

# %% [markdown]
# Now let's explore again this swap template, this time via its unique Id.

# %%
sofr_id = swap_templates[0].get("id", None)
print(sofr_id)

sofr_swap = load(resource_id=sofr_id)

print(json.dumps(sofr_swap.definition.as_dict(), indent=4))
# Out:
# a839a456-3ea5-4e8d-bc2e-a91e01ec876a
# {
#     "instrumentType": "VanillaSwap",
#     "template": {
#         "firstLeg": {
#             "rate": {
#                 "interestRateType": "FixedRate",
#                 "rate": {
#                     "value": 0.0,
#                     "unit": "Percentage"
#                 }
#             },
#             "interestPeriods": {
#                 "startDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "0D",
#                     "referenceDate": "SpotDate"
#                 },
#                 "endDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "10Y",
#                     "referenceDate": "StartDate"
#                 },
#                 "frequency": "Annual",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "rollConvention": "Same"
#             },
#             "paymentOffset": {
#                 "tenor": "2D",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "referenceDate": "PeriodEndDate",
#                 "direction": "Forward"
#             },
#             "couponDayCount": "Dcb_Actual_360",
#             "accrualDayCount": "Dcb_Actual_360",
#             "principal": {
#                 "currency": "USD",
#                 "amount": 10000000.0,
#                 "initialPrincipalExchange": false,
#                 "finalPrincipalExchange": false,
#                 "interimPrincipalExchange": false,
#                 "repaymentCurrency": "USD"
#             },
#             "payer": "Party1",
#             "receiver": "Party2"
#         },
#         "secondLeg": {
#             "rate": {
#                 "interestRateType": "FloatingRate",
#                 "index": "LSEG/USD_SOFR_ON_FRBNY",
#                 "spreadSchedule": [
#                     {
#                         "rate": {
#                             "value": 0.0,
#                             "unit": "BasisPoint"
#                         }
#                     }
#                 ],
#                 "resetDates": {
#                     "offset": {
#                         "tenor": "0D",
#                         "businessDayAdjustment": {
#                             "calendars": [],
#                             "convention": "ModifiedFollowing"
#                         },
#                         "referenceDate": "PeriodEndDate",
#                         "direction": "Backward"
#                     }
#                 },
#                 "leverage": 1.0
#             },
#             "interestPeriods": {
#                 "startDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "0D",
#                     "referenceDate": "SpotDate"
#                 },
#                 "endDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "10Y",
#                     "referenceDate": "StartDate"
#                 },
#                 "frequency": "Annual",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "rollConvention": "Same"
#             },
#             "paymentOffset": {
#                 "tenor": "2D",
#                 "businessDayAdjustment": {
#                     "calendars": [
#                         "USA"
#                     ],
#                     "convention": "NextBusinessDay"
#                 },
#                 "referenceDate": "PeriodEndDate",
#                 "direction": "Forward"
#             },
#             "couponDayCount": "Dcb_Actual_360",
#             "accrualDayCount": "Dcb_Actual_360",
#             "principal": {
#                 "currency": "USD",
#                 "amount": 10000000.0,
#                 "initialPrincipalExchange": false,
#                 "finalPrincipalExchange": false,
#                 "interimPrincipalExchange": false,
#                 "repaymentCurrency": "USD"
#             },
#             "payer": "Party2",
#             "receiver": "Party1"
#         }
#     }
# }
