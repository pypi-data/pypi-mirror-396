# %% [markdown]
# # Multiple Instrument Reference Data

# %% [markdown]
# This notebook demonstrates how to access and use the functinalities of **Instrument Reference** which are part of our **Yiedbook** module within LSEG Financial Analytics SDK.
#
# The main goal of this notebook is to explore and display different approaches in fetching multiple Instrument references by using 2 available methods:
# 1. Synchronous POST
# 2. Asynchronous POST

# %% [markdown]
# ## Imports

# %% [markdown]
# Import the following necessary modules:
#
# - *request_bond_indic_sync* - main Synchronous POST method
#
# - *request_bond_indic_async* - main Asynchronous POST method
#
# - *IdentifierInfo* - Class wrapper for instrument identifiers
#
# - *get_result* - method for obtaining results of Async method executions
#
# - *json* - for display purposes

# %%
from lseg_analytics.pricing.yield_book_rest import (
    request_bond_indic_sync,
    request_bond_indic_async,
    IdentifierInfo,
    get_result
)
import json as js

import time

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# As the post method consumes an input argument containing a list of identifiers, here's how to prepare it (can be 1-to-N entries):

# %%
# List of instruments defined by either CUSIP or ISIN identifiers 
instrument_input=[IdentifierInfo(identifier="91282CLF6"),
                    IdentifierInfo(identifier="US1352752"),
                    IdentifierInfo(identifier="999818YT")]

# %% [markdown]
# ## Synchronous POST Data retrieval

# %% [markdown]
# Once the data is prepared, it can be provided to the main method execution for data retrieval:

# %%
# Request single/multiple bond indices with sync post
sync_response = request_bond_indic_sync(input=instrument_input)

# %% [markdown]
# ## Asynchronous POST Data retrieval

# %% [markdown]
# Main difference in Sync and Async approach is that execution of async methods leaves room for further code execution on user's side and the user can 'collect' the results whenever he needs them (if execution is finished by then).
#
# So this approach has 2 steps:
# 1. Provide input data to execution method
# 2. Retrieve information by request_id received in step 1.

# %%
# Request multiple bond indices with async post
async_post_response = request_bond_indic_async(input=instrument_input)

attempt = 1

while attempt < 10:

    from lseg_analytics.core.exceptions import ResourceNotFound
    try:
        # Request bond indic with async post
        async_post_results_response = get_result(request_id_parameter=async_post_response.request_id)
        break
    except Exception as err:
        print(f"Attempt " + str(
            attempt) + " resulted in error retrieving results from:" + async_post_response.request_id)
        if (isinstance(err, ResourceNotFound)
                and f"The result is not ready yet for requestID:{async_post_response.request_id}" in str(err)):
            time.sleep(3)
            attempt += 1
        else:
            raise err

# %% [markdown]
# ## Display results

# %% [markdown]
# Results data is structured in JSON format so it can be easily displayed using print function.

# %% [markdown]
# ### Synchronous results

# %%
# Print results in json format
print(js.dumps(obj=sync_response.as_dict(), indent=4))
# Out:
# {
#     "meta": {
#         "status": "DONE",
#         "requestId": "R-150632",
#         "timeStamp": "2025-12-03T07:44:28Z",
#         "responseType": "BOND_INDIC",
#         "resultsStatus": "ALL"
#     },
#     "results": [
#         {
#             "isin": "US91282CLF67",
#             "cusip": "91282CLF6",
#             "indic": {
#                 "cfi": "DBFTFR",
#                 "ric": "91282CLF6=",
#                 "wkn": "A3L2GB",
#                 "figi": "BBG01P1YBJQ5",
#                 "frtb": {
#                     "sector": {
#                         "value": "Sovereigns including central banks"
#                     },
#                     "riskWeight": 0.5,
#                     "bucketNumber": 1,
#                     "creditQuality": "IG",
#                     "riskClassification": "CSR_NonSecuritised"
#                 },
#                 "isin": "US91282CLF67",
#                 "cusip": "91282CLF6",
#                 "moody": [
#                     {
#                         "value": "Aaa",
#                         "effectiveDate": "2024-08-15",
#                         "expirationDate": "2025-05-16"
#                     },
#                     {
#                         "value": "Aa1",
#                         "effectiveDate": "2025-05-16"
#                     }
#                 ],
#                 "permID": "232852133417",
#                 "source": "THOMREUT",
#                 "ticker": "US",
#                 "country": "US",
#                 "putFlag": false,
#                 "callFlag": false,
#                 "cobsCode": "DSOV",
#                 "country2": "US",
#                 "country3": "USA",
#                 "currency": "USD",
#                 "dayCount": "Act/Act",
#                 "glicCode": "SVGN",
#                 "regSFlag": false,
#                 "sinkFlag": false,
#                 "cmaTicker": "USA",
#                 "datedDate": "2024-08-15",
#                 "issueDate": "2024-08-15",
#                 "p144AFlag": false,
#                 "extendFlag": "N",
#                 "isoCountry": "US",
#                 "issuePrice": 99.303721,
#                 "issueYield": 3.96,
#                 "issuerName": {
#                     "value": "UNITED STATES TREASURY",
#                     "language": "en_US"
#                 },
#                 "marketType": "DOMC",
#                 "securityID": "91282CLF",
#                 "vPointType": "TBOND",
#                 "description": "US TREASURY",
#                 "esgBondFlag": false,
#                 "indexRating": "AA+",
#                 "issueAmount": 128895.363,
#                 "lowerRating": "AA+",
#                 "paymentFreq": 2,
#                 "securedFlag": false,
#                 "tierCapital": "NA",
#                 "deliveryFlag": "N",
#                 "indexCountry": "US",
#                 "industryCode": "G",
#                 "issuerTicker": "US",
#                 "lowestRating": "AA+",
#                 "maturityDate": "2034-08-15",
#                 "middleRating": "AA+",
#                 "minimumPiece": 100.0,
#                 "parentTicker": "US",
#                 "securityType": "BOND",
#                 "beyondRatings": {
#                     "esgGlobalScore": 86.885,
#                     "carbonGhgGdpRatio": 217.41,
#                     "esgSustainableGdp": 69985.193,
#                     "sovereignRiskScore": 68.293,
#                     "esgSustainableGdpGapRatio": -4.96,
#                     "sovereignImpliedCreditRisk": "AA"
#                 },
#                 "chapter11Flag": false,
#                 "currentCoupon": 3.875,
#                 "debtClassCode": "SRNT",
#                 "greenBondFlag": false,
#                 "highestRating": "AA+",
#                 "inDefaultFlag": false,
#                 "incomeCountry": "US",
#                 "issuerCountry": "US",
#                 "seniorityType": "SR",
#                 "assetClassCode": "TG",
#                 "cgmiSectorCode": "DSOV",
#                 "incomeCountry3": "USA",
#                 "instrumentType": "NT",
#                 "issuerCountry2": "US",
#                 "issuerCountry3": "USA",
#                 "lowestRatingNF": "AA+",
#                 "risingStarFlag": false,
#                 "vPointCategory": "CR",
#                 "bloombergTicker": "WIT 4.125 08/15/34",
#                 "fallenAngelFlag": false,
#                 "firstCouponDate": "2025-02-15",
#                 "industrySubCode": "NA",
#                 "outstandingDate": "2025-03-19",
#                 "redemptionValue": 100.0,
#                 "securitySubType": "TBOND",
#                 "tradeConvention": "w. Accrd",
#                 "securityCalcType": "GOVT",
#                 "assetClassSubCode": "SVGN",
#                 "finalMaturityDate": "2034-08-15",
#                 "issuerRatingMoody": "Aa1",
#                 "modifiedTimeStamp": "2025-05-17T00:38:57Z",
#                 "outstandingAmount": 119845.0692,
#                 "parentDescription": "UNITED STATES TREASURY",
#                 "issuerLowestRating": "AA+",
#                 "issuerMiddleRating": "AA+",
#                 "industryDescription": "Government Sector",
#                 "issuerHighestRating": "AA+",
#                 "leveragedBuyoutFlag": false,
#                 "clearingOrganization": "FRB",
#                 "currentHighYieldFlag": false,
#                 "debtClassDescription": "Sr Note",
#                 "privatePlacementFlag": false,
#                 "cgmiSectorDescription": "Domestic Sovereign",
#                 "originalHighYieldFlag": false,
#                 "defaultHorizonPYMethod": "OAS Change",
#                 "industrySubDescription": "NA",
#                 "assetClassSubDescription": "Sovereign Government"
#             },
#             "ticker": "US",
#             "country": "US",
#             "currency": "USD",
#             "identifier": "91282CLF",
#             "description": "US TREASURY",
#             "issuerTicker": "US",
#             "maturityDate": "2034-08-15",
#             "securityType": "BOND",
#             "currentCoupon": 3.875,
#             "securitySubType": "TBOND"
#         },
#         {
#             "isin": "XS2121367192",
#             "cusip": "US1352752",
#             "indic": {
#                 "cfi": "DBFNBR",
#                 "ric": "US212136719=",
#                 "wkn": "A28T5T",
#                 "figi": "BBG00RR4Q879",
#                 "frtb": {
#                     "sector": {
#                         "value": "Telecommunications"
#                     },
#                     "riskWeight": 2.0,
#                     "bucketNumber": 6,
#                     "creditQuality": "IG",
#                     "riskClassification": "CSR_NonSecuritised"
#                 },
#                 "isin": "XS2121367192",
#                 "tpex": "F04405",
#                 "cusip": "US1352752",
#                 "moody": [
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2020-02-14",
#                         "expirationDate": "2021-03-12"
#                     },
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2021-03-12",
#                         "expirationDate": "2021-05-17"
#                     },
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2021-05-17",
#                         "expirationDate": "2024-05-17"
#                     },
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2024-05-17",
#                         "expirationDate": "2025-08-26"
#                     },
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2025-08-26"
#                     }
#                 ],
#                 "permID": "192881291390",
#                 "source": "THOMREUT",
#                 "ticker": "T",
#                 "country": "US",
#                 "putFlag": false,
#                 "callFlag": true,
#                 "cobsCode": "DIVT",
#                 "country2": "US",
#                 "country3": "USA",
#                 "currency": "USD",
#                 "dayCount": "30/360 e",
#                 "glicCode": "UTEL",
#                 "regSFlag": false,
#                 "sinkFlag": false,
#                 "callDelay": 10,
#                 "cmaTicker": "SBC",
#                 "datedDate": "2020-02-27",
#                 "issueDate": "2020-02-27",
#                 "p144AFlag": false,
#                 "commonCode": "212136719",
#                 "extendFlag": "N",
#                 "isoCountry": "US",
#                 "issuePrice": 100.0,
#                 "issuerName": {
#                     "value": "AT&T INC",
#                     "language": "en_US"
#                 },
#                 "marketType": "EURO",
#                 "securityID": "US135275",
#                 "vPointType": "EURO",
#                 "description": "AT&T INC",
#                 "esgBondFlag": false,
#                 "indexRating": "BBB",
#                 "issueAmount": 2995.0,
#                 "lowerRating": "BBB",
#                 "paymentFreq": 2,
#                 "securedFlag": false,
#                 "tierCapital": "NA",
#                 "deliveryFlag": "N",
#                 "euroCallFlag": true,
#                 "indexCountry": "US",
#                 "industryCode": "U",
#                 "issuerTicker": "T",
#                 "lowestRating": "BBB",
#                 "maturityDate": "2049-06-01",
#                 "middleRating": "BBB",
#                 "minimumPiece": 100000.0,
#                 "nextCallDate": "2026-06-01",
#                 "parentTicker": "T",
#                 "securityType": "BOND",
#                 "chapter11Flag": false,
#                 "currentCoupon": 4.0,
#                 "debtClassCode": "SRNT",
#                 "greenBondFlag": false,
#                 "highestRating": "BBB+",
#                 "inDefaultFlag": false,
#                 "incomeCountry": "US",
#                 "issuerCountry": "US",
#                 "nextCallPrice": 100.0,
#                 "seniorityType": "SR",
#                 "assetClassCode": "CR",
#                 "cgmiSectorCode": "DIVT",
#                 "incomeCountry3": "USA",
#                 "instrumentType": "NT",
#                 "issuerCountry2": "US",
#                 "issuerCountry3": "USA",
#                 "lowestRatingNF": "BBB",
#                 "risingStarFlag": false,
#                 "vPointCategory": "CR",
#                 "bloombergTicker": "T 4 06/01/49 GMTN",
#                 "fallenAngelFlag": false,
#                 "firstCouponDate": "2020-06-01",
#                 "industrySubCode": "TE",
#                 "outstandingDate": "2020-02-27",
#                 "redemptionValue": 100.0,
#                 "restrictionDate": "2025-06-01",
#                 "securitySubType": "EURO",
#                 "tradeConvention": "w. Accrd",
#                 "securityCalcType": "BOND",
#                 "assetClassSubCode": "UTEL",
#                 "corporateESGScore": {
#                     "esgenvScore": 80.846,
#                     "esggovScore": 58.634,
#                     "esgsocScore": 85.883,
#                     "esgglobalScore": 77.636,
#                     "esgcommunityScore": 95.139,
#                     "esgemissionsScore": 87.931,
#                     "esgworkforceScore": 67.824,
#                     "esginnovationScore": 58.148,
#                     "esgmanagementScore": 54.469,
#                     "esgcsrStrategyScore": 82.471,
#                     "esghumanRightsScore": 83.333,
#                     "esgresourceUseScore": 93.622,
#                     "esgshareholdersScore": 56.626,
#                     "esgproductResponsibilityScore": 98.104
#                 },
#                 "finalMaturityDate": "2049-06-01",
#                 "issuerRatingMoody": "WR",
#                 "modifiedTimeStamp": "2025-08-28T20:59:49Z",
#                 "outstandingAmount": 2995.0,
#                 "parentDescription": "AT&T INC",
#                 "issuerLowestRating": "BBB",
#                 "issuerMiddleRating": "BBB",
#                 "dataUnderwriterList": [
#                     {
#                         "name": "BCC",
#                         "rank": 5,
#                         "split": 0.0
#                     },
#                     {
#                         "name": "BNP",
#                         "rank": 5,
#                         "split": 0.0
#                     },
#                     {
#                         "name": "DBK",
#                         "rank": 5,
#                         "split": 0.0
#                     },
#                     {
#                         "name": "MST",
#                         "rank": 5,
#                         "split": 0.0
#                     }
#                 ],
#                 "industryDescription": "Utility Sector",
#                 "issuerHighestRating": "BBB",
#                 "leveragedBuyoutFlag": false,
#                 "clearingOrganization": "TDC",
#                 "currentHighYieldFlag": false,
#                 "dataCallScheduleList": [
#                     {
#                         "date": "2025-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2026-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2027-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2028-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2029-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2030-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2031-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2032-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2033-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2034-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2035-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2036-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2037-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2038-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2039-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2040-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2041-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2042-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2043-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2044-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2045-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2046-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2047-06-01",
#                         "price": 100.0
#                     },
#                     {
#                         "date": "2048-06-01",
#                         "price": 100.0
#                     }
#                 ],
#                 "debtClassDescription": "Sr Note",
#                 "privatePlacementFlag": false,
#                 "cgmiSectorDescription": "Diversified Telecom",
#                 "originalHighYieldFlag": false,
#                 "americanEuropeanOption": "EUROPEAN",
#                 "defaultHorizonPYMethod": "OAS Change",
#                 "industrySubDescription": "Telephone",
#                 "assetClassSubDescription": "Telecom"
#             },
#             "ticker": "T",
#             "country": "US",
#             "currency": "USD",
#             "identifier": "US135275",
#             "description": "AT&T INC",
#             "issuerTicker": "T",
#             "maturityDate": "2049-06-01",
#             "securityType": "BOND",
#             "currentCoupon": 4.0,
#             "securitySubType": "EURO"
#         },
#         {
#             "cusip": "999818YT8",
#             "indic": {
#                 "ltv": 91.0,
#                 "wam": 192,
#                 "figi": "BBG0033WXBV4",
#                 "cusip": "999818YT8",
#                 "moody": [
#                     {
#                         "value": "Aaa"
#                     }
#                 ],
#                 "source": "CITI",
#                 "ticker": "GNMA",
#                 "country": "US",
#                 "loanAge": 151,
#                 "lockout": 0,
#                 "putFlag": false,
#                 "callFlag": false,
#                 "cobsCode": "MTGE",
#                 "country2": "US",
#                 "country3": "USA",
#                 "currency": "USD",
#                 "dayCount": "30/360 eom",
#                 "glicCode": "MBS",
#                 "grossWAC": 4.0,
#                 "ioPeriod": 0,
#                 "poolCode": "NA",
#                 "sinkFlag": false,
#                 "cmaTicker": "N/A",
#                 "datedDate": "2013-05-01",
#                 "gnma2Flag": false,
#                 "percentVA": 11.01,
#                 "currentLTV": 27.6,
#                 "extendFlag": "N",
#                 "isoCountry": "US",
#                 "marketType": "DOMC",
#                 "percentDTI": 34.0,
#                 "percentFHA": 80.9,
#                 "percentInv": 0.0,
#                 "percentPIH": 0.15,
#                 "percentRHS": 7.94,
#                 "securityID": "999818YT",
#                 "serviceFee": 0.5,
#                 "vPointType": "MPGNMA",
#                 "adjustedLTV": 27.6,
#                 "combinedLTV": 90.7,
#                 "creditScore": 692,
#                 "description": "30-YR GNMA-2013 PROD",
#                 "esgBondFlag": false,
#                 "indexRating": "AA+",
#                 "issueAmount": 8597.24,
#                 "lowerRating": "AA+",
#                 "paymentFreq": 12,
#                 "percentHARP": 0.0,
#                 "percentRefi": 63.6,
#                 "tierCapital": "NA",
#                 "balloonMonth": 0,
#                 "deliveryFlag": "N",
#                 "indexCountry": "US",
#                 "industryCode": "MT",
#                 "issuerTicker": "GNMA",
#                 "lowestRating": "AA+",
#                 "maturityDate": "2041-12-01",
#                 "middleRating": "AA+",
#                 "modifiedDate": "2025-11-14",
#                 "originalTerm": 360,
#                 "parentTicker": "GNMA",
#                 "percentHARP2": 0.0,
#                 "percentJumbo": 0.0,
#                 "securityType": "MORT",
#                 "currentCoupon": 3.5,
#                 "dataStateList": [
#                     {
#                         "state": "PR",
#                         "percent": 17.28
#                     },
#                     {
#                         "state": "TX",
#                         "percent": 10.02
#                     },
#                     {
#                         "state": "FL",
#                         "percent": 5.65
#                     },
#                     {
#                         "state": "CA",
#                         "percent": 4.98
#                     },
#                     {
#                         "state": "NY",
#                         "percent": 4.79
#                     },
#                     {
#                         "state": "OH",
#                         "percent": 4.77
#                     },
#                     {
#                         "state": "GA",
#                         "percent": 4.43
#                     },
#                     {
#                         "state": "PA",
#                         "percent": 3.39
#                     },
#                     {
#                         "state": "MI",
#                         "percent": 3.02
#                     },
#                     {
#                         "state": "NC",
#                         "percent": 2.73
#                     },
#                     {
#                         "state": "VA",
#                         "percent": 2.68
#                     },
#                     {
#                         "state": "IL",
#                         "percent": 2.62
#                     },
#                     {
#                         "state": "NJ",
#                         "percent": 2.42
#                     },
#                     {
#                         "state": "IN",
#                         "percent": 2.35
#                     },
#                     {
#                         "state": "MD",
#                         "percent": 2.18
#                     },
#                     {
#                         "state": "MO",
#                         "percent": 2.11
#                     },
#                     {
#                         "state": "AZ",
#                         "percent": 1.73
#                     },
#                     {
#                         "state": "TN",
#                         "percent": 1.66
#                     },
#                     {
#                         "state": "WA",
#                         "percent": 1.48
#                     },
#                     {
#                         "state": "AL",
#                         "percent": 1.46
#                     },
#                     {
#                         "state": "LA",
#                         "percent": 1.23
#                     },
#                     {
#                         "state": "OK",
#                         "percent": 1.22
#                     },
#                     {
#                         "state": "MN",
#                         "percent": 1.18
#                     },
#                     {
#                         "state": "SC",
#                         "percent": 1.11
#                     },
#                     {
#                         "state": "CT",
#                         "percent": 1.1
#                     },
#                     {
#                         "state": "KY",
#                         "percent": 1.05
#                     },
#                     {
#                         "state": "CO",
#                         "percent": 1.01
#                     },
#                     {
#                         "state": "WI",
#                         "percent": 1.01
#                     },
#                     {
#                         "state": "NM",
#                         "percent": 0.96
#                     },
#                     {
#                         "state": "MS",
#                         "percent": 0.95
#                     },
#                     {
#                         "state": "OR",
#                         "percent": 0.91
#                     },
#                     {
#                         "state": "AR",
#                         "percent": 0.76
#                     },
#                     {
#                         "state": "NV",
#                         "percent": 0.7
#                     },
#                     {
#                         "state": "MA",
#                         "percent": 0.65
#                     },
#                     {
#                         "state": "IA",
#                         "percent": 0.61
#                     },
#                     {
#                         "state": "UT",
#                         "percent": 0.58
#                     },
#                     {
#                         "state": "KS",
#                         "percent": 0.57
#                     },
#                     {
#                         "state": "DE",
#                         "percent": 0.44
#                     },
#                     {
#                         "state": "ID",
#                         "percent": 0.4
#                     },
#                     {
#                         "state": "NE",
#                         "percent": 0.38
#                     },
#                     {
#                         "state": "WV",
#                         "percent": 0.27
#                     },
#                     {
#                         "state": "ME",
#                         "percent": 0.19
#                     },
#                     {
#                         "state": "HI",
#                         "percent": 0.16
#                     },
#                     {
#                         "state": "NH",
#                         "percent": 0.16
#                     },
#                     {
#                         "state": "MT",
#                         "percent": 0.13
#                     },
#                     {
#                         "state": "AK",
#                         "percent": 0.12
#                     },
#                     {
#                         "state": "RI",
#                         "percent": 0.12
#                     },
#                     {
#                         "state": "WY",
#                         "percent": 0.08
#                     },
#                     {
#                         "state": "SD",
#                         "percent": 0.07
#                     },
#                     {
#                         "state": "VT",
#                         "percent": 0.06
#                     },
#                     {
#                         "state": "DC",
#                         "percent": 0.04
#                     },
#                     {
#                         "state": "ND",
#                         "percent": 0.04
#                     }
#                 ],
#                 "delinquencies": {
#                     "del30Days": {
#                         "percent": 2.26
#                     },
#                     "del60Days": {
#                         "percent": 0.61
#                     },
#                     "del90Days": {
#                         "percent": 0.22
#                     },
#                     "del90PlusDays": {
#                         "percent": 0.69
#                     },
#                     "del120PlusDays": {
#                         "percent": 0.47
#                     }
#                 },
#                 "greenBondFlag": false,
#                 "highestRating": "AAA",
#                 "incomeCountry": "US",
#                 "issuerCountry": "US",
#                 "percentSecond": 0.0,
#                 "poolAgeMethod": "Calculated",
#                 "prepayEffDate": "2025-10-01",
#                 "seniorityType": "NA",
#                 "assetClassCode": "CO",
#                 "cgmiSectorCode": "MTGE",
#                 "cleanPayMonths": 0,
#                 "collateralType": "GNMA",
#                 "fullPledgeFlag": false,
#                 "gpmPercentStep": 0.0,
#                 "incomeCountry3": "USA",
#                 "instrumentType": "NA",
#                 "issuerCountry2": "US",
#                 "issuerCountry3": "USA",
#                 "lowestRatingNF": "AA+",
#                 "poolIssuerName": "NA",
#                 "vPointCategory": "RP",
#                 "amortizedFHALTV": 62.1,
#                 "bloombergTicker": "GNSF 3.5 2013",
#                 "industrySubCode": "MT",
#                 "originationDate": "2013-05-01",
#                 "originationYear": 2013,
#                 "percent2To4Unit": 2.7,
#                 "percentHAMPMods": 0.9,
#                 "percentPurchase": 32.0,
#                 "percentStateHFA": 0.4,
#                 "poolOriginalWAM": 0,
#                 "preliminaryFlag": false,
#                 "redemptionValue": 100.0,
#                 "securitySubType": "MPGNMA",
#                 "dataQuartileList": [
#                     {
#                         "ltvlow": 17.0,
#                         "ltvhigh": 87.0,
#                         "loanSizeLow": 22000.0,
#                         "loanSizeHigh": 101000.0,
#                         "percentDTILow": 10.0,
#                         "creditScoreLow": 300.0,
#                         "percentDTIHigh": 24.4,
#                         "creditScoreHigh": 655.0,
#                         "originalLoanAgeLow": 0,
#                         "originationYearLow": 20101101,
#                         "originalLoanAgeHigh": 0,
#                         "originationYearHigh": 20130401
#                     },
#                     {
#                         "ltvlow": 87.0,
#                         "ltvhigh": 93.0,
#                         "loanSizeLow": 101000.0,
#                         "loanSizeHigh": 132000.0,
#                         "percentDTILow": 24.4,
#                         "creditScoreLow": 655.0,
#                         "percentDTIHigh": 34.9,
#                         "creditScoreHigh": 691.0,
#                         "originalLoanAgeLow": 0,
#                         "originationYearLow": 20130401,
#                         "originalLoanAgeHigh": 0,
#                         "originationYearHigh": 20130501
#                     },
#                     {
#                         "ltvlow": 93.0,
#                         "ltvhigh": 97.0,
#                         "loanSizeLow": 132000.0,
#                         "loanSizeHigh": 183000.0,
#                         "percentDTILow": 34.9,
#                         "creditScoreLow": 691.0,
#                         "percentDTIHigh": 43.6,
#                         "creditScoreHigh": 738.0,
#                         "originalLoanAgeLow": 0,
#                         "originationYearLow": 20130501,
#                         "originalLoanAgeHigh": 1,
#                         "originationYearHigh": 20130701
#                     },
#                     {
#                         "ltvlow": 97.0,
#                         "ltvhigh": 118.0,
#                         "loanSizeLow": 183000.0,
#                         "loanSizeHigh": 743000.0,
#                         "percentDTILow": 43.6,
#                         "creditScoreLow": 738.0,
#                         "percentDTIHigh": 65.0,
#                         "creditScoreHigh": 832.0,
#                         "originalLoanAgeLow": 1,
#                         "originationYearLow": 20130701,
#                         "originalLoanAgeHigh": 43,
#                         "originationYearHigh": 20141101
#                     }
#                 ],
#                 "gpmNumberOfSteps": 0,
#                 "percentHARPOwner": 0.0,
#                 "percentPrincipal": 100.0,
#                 "securityCalcType": "GNMA",
#                 "assetClassSubCode": "MBS",
#                 "forbearanceAmount": 0.0,
#                 "modifiedTimeStamp": "2025-11-14T17:21:00Z",
#                 "outstandingAmount": 1049.36,
#                 "parentDescription": "NA",
#                 "poolIsBalloonFlag": false,
#                 "prepaymentOptions": {
#                     "prepayType": [
#                         "CPR",
#                         "PSA",
#                         "VEC"
#                     ]
#                 },
#                 "reperformerMonths": 1,
#                 "dataPPMHistoryList": [
#                     {
#                         "prepayType": "PSA",
#                         "dataPPMHistoryDetailList": [
#                             {
#                                 "month": "1",
#                                 "prepayRate": 114.1334
#                             },
#                             {
#                                 "month": "3",
#                                 "prepayRate": 108.6911
#                             },
#                             {
#                                 "month": "6",
#                                 "prepayRate": 105.6514
#                             },
#                             {
#                                 "month": "12",
#                                 "prepayRate": 103.3021
#                             },
#                             {
#                                 "month": "24",
#                                 "prepayRate": 0.0
#                             }
#                         ]
#                     },
#                     {
#                         "prepayType": "CPR",
#                         "dataPPMHistoryDetailList": [
#                             {
#                                 "month": "1",
#                                 "prepayRate": 6.848
#                             },
#                             {
#                                 "month": "3",
#                                 "prepayRate": 6.5215
#                             },
#                             {
#                                 "month": "6",
#                                 "prepayRate": 6.3391
#                             },
#                             {
#                                 "month": "12",
#                                 "prepayRate": 6.1981
#                             },
#                             {
#                                 "month": "24",
#                                 "prepayRate": 0.0
#                             }
#                         ]
#                     }
#                 ],
#                 "daysToFirstPayment": 44,
#                 "issuerLowestRating": "NA",
#                 "issuerMiddleRating": "NA",
#                 "newCurrentLoanSize": 100633.0,
#                 "originationChannel": {
#                     "broker": 4.68,
#                     "retail": 61.86,
#                     "unknown": 0.0,
#                     "unspecified": 0.0,
#                     "correspondence": 33.46
#                 },
#                 "percentMultiFamily": 2.7,
#                 "percentRefiCashout": 5.8,
#                 "percentRegularMods": 3.6,
#                 "percentReperformer": 0.5,
#                 "relocationLoanFlag": false,
#                 "socialDensityScore": 0.0,
#                 "umbsfhlgPercentage": 0.0,
#                 "umbsfnmaPercentage": 0.0,
#                 "industryDescription": "Mortgage",
#                 "issuerHighestRating": "NA",
#                 "newOriginalLoanSize": 182005.0,
#                 "socialCriteriaShare": 0.0,
#                 "spreadAtOrigination": 22.2,
#                 "weightedAvgLoanSize": 100633.0,
#                 "poolOriginalLoanSize": 182005.0,
#                 "cgmiSectorDescription": "Mortgage",
#                 "cleanPayAverageMonths": 0,
#                 "expModelAvailableFlag": true,
#                 "fhfaImpliedCurrentLTV": 27.6,
#                 "percentRefiNonCashout": 57.8,
#                 "prepayPenaltySchedule": "0.000",
#                 "defaultHorizonPYMethod": "OAS Change",
#                 "industrySubDescription": "Mortgage Asset Backed",
#                 "actualPrepayHistoryList": {
#                     "date": "2026-01-01",
#                     "genericValue": 1.0104
#                 },
#                 "adjustedCurrentLoanSize": 100633.0,
#                 "forbearanceModification": 0.0,
#                 "percentTwoPlusBorrowers": 43.9,
#                 "poolAvgOriginalLoanTerm": 0,
#                 "adjustedOriginalLoanSize": 181994.0,
#                 "assetClassSubDescription": "Collateralized Asset Backed - Mortgage",
#                 "mortgageInsurancePremium": {
#                     "annual": {
#                         "va": 0.0,
#                         "fha": 0.797,
#                         "pih": 0.0,
#                         "rhs": 0.399
#                     },
#                     "upfront": {
#                         "va": 0.5,
#                         "fha": 0.694,
#                         "pih": 1.0,
#                         "rhs": 1.996
#                     }
#                 },
#                 "percentReperformerAndMod": 0.1,
#                 "reperformerMonthsForMods": 2,
#                 "originalLoanSizeRemaining": 150963.0,
#                 "percentFirstTimeHomeBuyer": 20.9,
#                 "current3rdPartyOrigination": 38.14,
#                 "adjustedSpreadAtOrigination": 22.2,
#                 "dataPrepayModelServicerList": [
#                     {
#                         "percent": 23.73,
#                         "servicer": "FREE"
#                     },
#                     {
#                         "percent": 11.9,
#                         "servicer": "NSTAR"
#                     },
#                     {
#                         "percent": 11.23,
#                         "servicer": "BCPOP"
#                     },
#                     {
#                         "percent": 7.2,
#                         "servicer": "QUICK"
#                     },
#                     {
#                         "percent": 7.16,
#                         "servicer": "PENNY"
#                     },
#                     {
#                         "percent": 6.47,
#                         "servicer": "LAKEV"
#                     },
#                     {
#                         "percent": 6.38,
#                         "servicer": "CARRG"
#                     },
#                     {
#                         "percent": 5.5,
#                         "servicer": "USB"
#                     },
#                     {
#                         "percent": 3.61,
#                         "servicer": "WELLS"
#                     },
#                     {
#                         "percent": 2.4,
#                         "servicer": "PNC"
#                     },
#                     {
#                         "percent": 1.35,
#                         "servicer": "MNTBK"
#                     },
#                     {
#                         "percent": 1.16,
#                         "servicer": "NWRES"
#                     },
#                     {
#                         "percent": 0.95,
#                         "servicer": "FIFTH"
#                     },
#                     {
#                         "percent": 0.75,
#                         "servicer": "DEPOT"
#                     },
#                     {
#                         "percent": 0.61,
#                         "servicer": "BOKF"
#                     },
#                     {
#                         "percent": 0.49,
#                         "servicer": "JPM"
#                     },
#                     {
#                         "percent": 0.48,
#                         "servicer": "TRUIS"
#                     },
#                     {
#                         "percent": 0.43,
#                         "servicer": "CITI"
#                     },
#                     {
#                         "percent": 0.39,
#                         "servicer": "GUILD"
#                     },
#                     {
#                         "percent": 0.21,
#                         "servicer": "CNTRL"
#                     },
#                     {
#                         "percent": 0.21,
#                         "servicer": "REGNS"
#                     },
#                     {
#                         "percent": 0.09,
#                         "servicer": "COLNL"
#                     },
#                     {
#                         "percent": 0.06,
#                         "servicer": "HFAGY"
#                     },
#                     {
#                         "percent": 0.06,
#                         "servicer": "MNSRC"
#                     }
#                 ],
#                 "nonWeightedOriginalLoanSize": 0.0,
#                 "original3rdPartyOrigination": 0.0,
#                 "percentHARPDec2010Extension": 0.0,
#                 "percentHARPOneYearExtension": 0.0,
#                 "percentDownPaymentAssistance": 5.6,
#                 "percentAmortizedFHALTVUnder78": 95.4,
#                 "loanPerformanceImpliedCurrentLTV": 43.6,
#                 "reperformerMonthsForReperformers": 28
#             },
#             "ticker": "GNMA",
#             "country": "US",
#             "currency": "USD",
#             "identifier": "999818YT",
#             "description": "30-YR GNMA-2013 PROD",
#             "issuerTicker": "GNMA",
#             "maturityDate": "2041-12-01",
#             "securityType": "MORT",
#             "currentCoupon": 3.5,
#             "securitySubType": "MPGNMA"
#         }
#     ]
# }

# %% [markdown]
# ### Asynchronous results

# %%
# Print results in json format
print(js.dumps(async_post_results_response, indent=4))
# Out:
# {
#     "meta": {
#         "status": "DONE",
#         "requestId": "R-1572679",
#         "timeStamp": "2025-06-12T04:20:20Z",
#         "responseType": "BOND_INDIC",
#         "resultsStatus": "ALL"
#     },
#     "results": [
#         {
#             "isin": "US91282CLF67",
#             "cusip": "91282CLF6",
#             "indic": {
#                 "cfi": "DBFTFR",
#                 "ric": "91282CLF6=",
#                 "wkn": "A3L2GB",
#                 "figi": "BBG01P1YBJQ5",
#                 "frtb": {
#                     "sector": {
#                         "value": "Sovereigns including central banks"
#                     },
#                     "riskWeight": 0.5,
#                     "bucketNumber": 1,
#                     "creditQuality": "IG",
#                     "riskClassification": "CSR_NonSecuritised"
#                 },
#                 "isin": "US91282CLF67",
#                 "cusip": "91282CLF6",
#                 "moody": [
#                     {
#                         "value": "Aaa",
#                         "effectiveDate": "2024-08-15",
#                         "expirationDate": "2025-05-16"
#                     },
#                     {
#                         "value": "Aa1",
#                         "effectiveDate": "2025-05-16"
#                     }
#                 ],
#                 "permID": "232852133417",
#                 "source": "THOMREUT",
#                 "ticker": "US",
#                 "country": "US",
#                 "putFlag": false,
#                 "callFlag": false,
#                 "cobsCode": "DSOV",
#                 "country2": "US",
#                 "country3": "USA",
#                 "currency": "USD",
#                 "dayCount": "Act/Act",
#                 "glicCode": "SVGN",
#                 "regSFlag": false,
#                 "sinkFlag": false,
#                 "cmaTicker": "USA",
#                 "datedDate": "2024-08-15",
#                 "issueDate": "2024-08-15",
#                 "p144AFlag": false,
#                 "extendFlag": "N",
#                 "isoCountry": "US",
#                 "issuePrice": 99.303721,
#                 "issueYield": 3.96,
#                 "issuerName": {
#                     "value": "UNITED STATES TREASURY",
#                     "language": "en_US"
#                 },
#                 "marketType": "DOMC",
#                 "securityID": "91282CLF",
#                 "vPointType": "TBOND",
#                 "description": "US TREASURY",
#                 "esgBondFlag": false,
#                 "indexRating": "AA+",
#                 "issueAmount": 128895.363,
#                 "lowerRating": "AA+",
#                 "paymentFreq": 2,
#                 "securedFlag": false,
#                 "tierCapital": "NA",
#                 "deliveryFlag": "N",
#                 "indexCountry": "US",
#                 "industryCode": "G",
#                 "issuerTicker": "US",
#                 "lowestRating": "AA+",
#                 "maturityDate": "2034-08-15",
#                 "middleRating": "AA+",
#                 "minimumPiece": 100,
#                 "parentTicker": "US",
#                 "securityType": "BOND",
#                 "beyondRatings": {
#                     "esgGlobalScore": 86.885,
#                     "carbonGhgGdpRatio": 217.41,
#                     "esgSustainableGdp": 69985.193,
#                     "sovereignRiskScore": 68.293,
#                     "esgSustainableGdpGapRatio": -4.96,
#                     "sovereignImpliedCreditRisk": "AA"
#                 },
#                 "chapter11Flag": false,
#                 "currentCoupon": 3.875,
#                 "debtClassCode": "SRNT",
#                 "greenBondFlag": false,
#                 "highestRating": "AA+",
#                 "inDefaultFlag": false,
#                 "incomeCountry": "US",
#                 "issuerCountry": "US",
#                 "seniorityType": "SR",
#                 "assetClassCode": "TG",
#                 "cgmiSectorCode": "DSOV",
#                 "incomeCountry3": "USA",
#                 "instrumentType": "NT",
#                 "issuerCountry2": "US",
#                 "issuerCountry3": "USA",
#                 "lowestRatingNF": "AA+",
#                 "risingStarFlag": false,
#                 "vPointCategory": "CR",
#                 "bloombergTicker": "WIT 4.125 08/15/34",
#                 "fallenAngelFlag": false,
#                 "firstCouponDate": "2025-02-15",
#                 "industrySubCode": "NA",
#                 "outstandingDate": "2025-03-19",
#                 "redemptionValue": 100,
#                 "securitySubType": "TBOND",
#                 "tradeConvention": "w. Accrd",
#                 "securityCalcType": "GOVT",
#                 "assetClassSubCode": "SVGN",
#                 "finalMaturityDate": "2034-08-15",
#                 "issuerRatingMoody": "Aa1",
#                 "modifiedTimeStamp": "2025-05-17T00:38:57Z",
#                 "outstandingAmount": 119845.0692,
#                 "parentDescription": "UNITED STATES TREASURY",
#                 "issuerLowestRating": "AA+",
#                 "issuerMiddleRating": "AA+",
#                 "industryDescription": "Government Sector",
#                 "issuerHighestRating": "AA+",
#                 "leveragedBuyoutFlag": false,
#                 "clearingOrganization": "FRB",
#                 "currentHighYieldFlag": false,
#                 "debtClassDescription": "Sr Note",
#                 "privatePlacementFlag": false,
#                 "cgmiSectorDescription": "Domestic Sovereign",
#                 "originalHighYieldFlag": false,
#                 "defaultHorizonPYMethod": "OAS Change",
#                 "industrySubDescription": "NA",
#                 "assetClassSubDescription": "Sovereign Government"
#             },
#             "ticker": "US",
#             "country": "US",
#             "currency": "USD",
#             "identifier": "91282CLF",
#             "description": "US TREASURY",
#             "issuerTicker": "US",
#             "maturityDate": "2034-08-15",
#             "securityType": "BOND",
#             "currentCoupon": 3.875,
#             "securitySubType": "TBOND"
#         },
#         {
#             "isin": "XS2121367192",
#             "cusip": "US1352752",
#             "indic": {
#                 "cfi": "DBFNBR",
#                 "ric": "US212136719=",
#                 "wkn": "A28T5T",
#                 "figi": "BBG00RR4Q879",
#                 "frtb": {
#                     "sector": {
#                         "value": "Telecommunications"
#                     },
#                     "riskWeight": 2,
#                     "bucketNumber": 6,
#                     "creditQuality": "IG",
#                     "riskClassification": "CSR_NonSecuritised"
#                 },
#                 "isin": "XS2121367192",
#                 "tpex": "F04405",
#                 "cusip": "US1352752",
#                 "moody": [
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2020-02-14",
#                         "expirationDate": "2021-03-12"
#                     },
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2021-03-12",
#                         "expirationDate": "2021-05-17"
#                     },
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2021-05-17",
#                         "expirationDate": "2024-05-17"
#                     },
#                     {
#                         "value": "Baa2",
#                         "effectiveDate": "2024-05-17"
#                     }
#                 ],
#                 "permID": "192881291390",
#                 "source": "THOMREUT",
#                 "ticker": "T",
#                 "country": "US",
#                 "putFlag": false,
#                 "callFlag": true,
#                 "cobsCode": "DIVT",
#                 "country2": "US",
#                 "country3": "USA",
#                 "currency": "USD",
#                 "dayCount": "30/360 e",
#                 "glicCode": "UTEL",
#                 "regSFlag": false,
#                 "sinkFlag": false,
#                 "callDelay": 10,
#                 "cmaTicker": "SBC",
#                 "datedDate": "2020-02-27",
#                 "issueDate": "2020-02-27",
#                 "p144AFlag": false,
#                 "commonCode": "212136719",
#                 "extendFlag": "N",
#                 "isoCountry": "US",
#                 "issuePrice": 100,
#                 "issuerName": {
#                     "value": "AT&T INC",
#                     "language": "en_US"
#                 },
#                 "marketType": "EURO",
#                 "securityID": "US135275",
#                 "vPointType": "EURO",
#                 "description": "AT&T INC",
#                 "esgBondFlag": false,
#                 "indexRating": "BBB",
#                 "issueAmount": 2995,
#                 "lowerRating": "BBB",
#                 "paymentFreq": 2,
#                 "securedFlag": false,
#                 "tierCapital": "NA",
#                 "deliveryFlag": "N",
#                 "euroCallFlag": true,
#                 "indexCountry": "US",
#                 "industryCode": "U",
#                 "issuerTicker": "T",
#                 "lowestRating": "BBB",
#                 "maturityDate": "2049-06-01",
#                 "middleRating": "BBB",
#                 "minimumPiece": 100000,
#                 "nextCallDate": "2026-06-01",
#                 "parentTicker": "T",
#                 "securityType": "BOND",
#                 "chapter11Flag": false,
#                 "currentCoupon": 4,
#                 "debtClassCode": "SRNT",
#                 "greenBondFlag": false,
#                 "highestRating": "BBB+",
#                 "inDefaultFlag": false,
#                 "incomeCountry": "US",
#                 "issuerCountry": "US",
#                 "nextCallPrice": 100,
#                 "seniorityType": "SR",
#                 "assetClassCode": "CR",
#                 "cgmiSectorCode": "DIVT",
#                 "incomeCountry3": "USA",
#                 "instrumentType": "NT",
#                 "issuerCountry2": "US",
#                 "issuerCountry3": "USA",
#                 "lowestRatingNF": "BBB",
#                 "risingStarFlag": false,
#                 "vPointCategory": "CR",
#                 "bloombergTicker": "T 4 06/01/49 GMTN",
#                 "fallenAngelFlag": false,
#                 "firstCouponDate": "2020-06-01",
#                 "industrySubCode": "TE",
#                 "outstandingDate": "2020-02-27",
#                 "redemptionValue": 100,
#                 "restrictionDate": "2025-06-01",
#                 "securitySubType": "EURO",
#                 "tradeConvention": "w. Accrd",
#                 "securityCalcType": "BOND",
#                 "assetClassSubCode": "UTEL",
#                 "corporateESGScore": {
#                     "esgenvScore": 81.225,
#                     "esggovScore": 65.122,
#                     "esgsocScore": 92.908,
#                     "esgglobalScore": 83.168,
#                     "esgcommunityScore": 95.07,
#                     "esgemissionsScore": 87.626,
#                     "esgworkforceScore": 93.662,
#                     "esginnovationScore": 57.54,
#                     "esgmanagementScore": 64.599,
#                     "esgcsrStrategyScore": 94.568,
#                     "esghumanRightsScore": 85.112,
#                     "esgresourceUseScore": 95.55,
#                     "esgshareholdersScore": 47.235,
#                     "esgproductResponsibilityScore": 97.805
#                 },
#                 "finalMaturityDate": "2049-06-01",
#                 "issuerRatingMoody": "WR",
#                 "modifiedTimeStamp": "2025-04-13T16:18:17Z",
#                 "outstandingAmount": 2995,
#                 "parentDescription": "AT&T INC",
#                 "issuerLowestRating": "BBB",
#                 "issuerMiddleRating": "BBB",
#                 "dataUnderwriterList": [
#                     {
#                         "name": "BCC",
#                         "rank": 5,
#                         "split": 0
#                     },
#                     {
#                         "name": "BNP",
#                         "rank": 5,
#                         "split": 0
#                     },
#                     {
#                         "name": "DBK",
#                         "rank": 5,
#                         "split": 0
#                     },
#                     {
#                         "name": "MST",
#                         "rank": 5,
#                         "split": 0
#                     }
#                 ],
#                 "industryDescription": "Utility Sector",
#                 "issuerHighestRating": "BBB",
#                 "leveragedBuyoutFlag": false,
#                 "clearingOrganization": "TDC",
#                 "currentHighYieldFlag": false,
#                 "dataCallScheduleList": [
#                     {
#                         "date": "2025-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2026-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2027-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2028-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2029-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2030-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2031-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2032-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2033-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2034-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2035-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2036-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2037-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2038-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2039-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2040-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2041-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2042-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2043-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2044-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2045-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2046-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2047-06-01",
#                         "price": 100
#                     },
#                     {
#                         "date": "2048-06-01",
#                         "price": 100
#                     }
#                 ],
#                 "debtClassDescription": "Sr Note",
#                 "privatePlacementFlag": false,
#                 "cgmiSectorDescription": "Diversified Telecom",
#                 "originalHighYieldFlag": false,
#                 "americanEuropeanOption": "EUROPEAN",
#                 "defaultHorizonPYMethod": "OAS Change",
#                 "industrySubDescription": "Telephone",
#                 "assetClassSubDescription": "Telecom"
#             },
#             "ticker": "T",
#             "country": "US",
#             "currency": "USD",
#             "identifier": "US135275",
#             "description": "AT&T INC",
#             "issuerTicker": "T",
#             "maturityDate": "2049-06-01",
#             "securityType": "BOND",
#             "currentCoupon": 4,
#             "securitySubType": "EURO"
#         },
#         {
#             "cusip": "999818YT8",
#             "indic": {
#                 "ltv": 90,
#                 "wam": 198,
#                 "figi": "BBG0033WXBV4",
#                 "cusip": "999818YT8",
#                 "moody": [
#                     {
#                         "value": "Aaa"
#                     }
#                 ],
#                 "source": "CITI",
#                 "ticker": "GNMA",
#                 "country": "US",
#                 "loanAge": 145,
#                 "lockout": 0,
#                 "putFlag": false,
#                 "callFlag": false,
#                 "cobsCode": "MTGE",
#                 "country2": "US",
#                 "country3": "USA",
#                 "currency": "USD",
#                 "dayCount": "30/360 eom",
#                 "glicCode": "MBS",
#                 "grossWAC": 4,
#                 "ioPeriod": 0,
#                 "poolCode": "NA",
#                 "sinkFlag": false,
#                 "cmaTicker": "N/A",
#                 "datedDate": "2013-05-01",
#                 "gnma2Flag": false,
#                 "percentVA": 11.02,
#                 "currentLTV": 28,
#                 "extendFlag": "N",
#                 "isoCountry": "US",
#                 "marketType": "DOMC",
#                 "percentDTI": 33.9,
#                 "percentFHA": 80.98,
#                 "percentInv": 0,
#                 "percentPIH": 0.14,
#                 "percentRHS": 7.86,
#                 "securityID": "999818YT",
#                 "serviceFee": 0.5,
#                 "vPointType": "MPGNMA",
#                 "adjustedLTV": 28,
#                 "combinedLTV": 90.7,
#                 "creditScore": 692,
#                 "description": "30-YR GNMA-2013 PROD",
#                 "esgBondFlag": false,
#                 "indexRating": "AA+",
#                 "issueAmount": 8597.24,
#                 "lowerRating": "AA+",
#                 "paymentFreq": 12,
#                 "percentHARP": 0,
#                 "percentRefi": 63.9,
#                 "tierCapital": "NA",
#                 "balloonMonth": 0,
#                 "deliveryFlag": "N",
#                 "indexCountry": "US",
#                 "industryCode": "MT",
#                 "issuerTicker": "GNMA",
#                 "lowestRating": "AA+",
#                 "maturityDate": "2041-12-01",
#                 "middleRating": "AA+",
#                 "modifiedDate": "2025-05-13",
#                 "originalTerm": 360,
#                 "parentTicker": "GNMA",
#                 "percentHARP2": 0,
#                 "percentJumbo": 0,
#                 "securityType": "MORT",
#                 "currentCoupon": 3.5,
#                 "dataStateList": [
#                     {
#                         "state": "PR",
#                         "percent": 17
#                     },
#                     {
#                         "state": "TX",
#                         "percent": 10.12
#                     },
#                     {
#                         "state": "FL",
#                         "percent": 5.68
#                     },
#                     {
#                         "state": "CA",
#                         "percent": 4.89
#                     },
#                     {
#                         "state": "OH",
#                         "percent": 4.83
#                     },
#                     {
#                         "state": "NY",
#                         "percent": 4.77
#                     },
#                     {
#                         "state": "GA",
#                         "percent": 4.44
#                     },
#                     {
#                         "state": "PA",
#                         "percent": 3.35
#                     },
#                     {
#                         "state": "MI",
#                         "percent": 3.1
#                     },
#                     {
#                         "state": "NC",
#                         "percent": 2.72
#                     },
#                     {
#                         "state": "IL",
#                         "percent": 2.68
#                     },
#                     {
#                         "state": "VA",
#                         "percent": 2.67
#                     },
#                     {
#                         "state": "NJ",
#                         "percent": 2.39
#                     },
#                     {
#                         "state": "IN",
#                         "percent": 2.37
#                     },
#                     {
#                         "state": "MD",
#                         "percent": 2.26
#                     },
#                     {
#                         "state": "MO",
#                         "percent": 2.1
#                     },
#                     {
#                         "state": "AZ",
#                         "percent": 1.73
#                     },
#                     {
#                         "state": "TN",
#                         "percent": 1.67
#                     },
#                     {
#                         "state": "AL",
#                         "percent": 1.47
#                     },
#                     {
#                         "state": "WA",
#                         "percent": 1.47
#                     },
#                     {
#                         "state": "OK",
#                         "percent": 1.22
#                     },
#                     {
#                         "state": "LA",
#                         "percent": 1.21
#                     },
#                     {
#                         "state": "MN",
#                         "percent": 1.2
#                     },
#                     {
#                         "state": "SC",
#                         "percent": 1.12
#                     },
#                     {
#                         "state": "CT",
#                         "percent": 1.08
#                     },
#                     {
#                         "state": "KY",
#                         "percent": 1.04
#                     },
#                     {
#                         "state": "CO",
#                         "percent": 1.03
#                     },
#                     {
#                         "state": "WI",
#                         "percent": 1.01
#                     },
#                     {
#                         "state": "MS",
#                         "percent": 0.96
#                     },
#                     {
#                         "state": "NM",
#                         "percent": 0.94
#                     },
#                     {
#                         "state": "OR",
#                         "percent": 0.88
#                     },
#                     {
#                         "state": "AR",
#                         "percent": 0.75
#                     },
#                     {
#                         "state": "NV",
#                         "percent": 0.69
#                     },
#                     {
#                         "state": "MA",
#                         "percent": 0.68
#                     },
#                     {
#                         "state": "IA",
#                         "percent": 0.62
#                     },
#                     {
#                         "state": "KS",
#                         "percent": 0.59
#                     },
#                     {
#                         "state": "UT",
#                         "percent": 0.59
#                     },
#                     {
#                         "state": "DE",
#                         "percent": 0.44
#                     },
#                     {
#                         "state": "ID",
#                         "percent": 0.39
#                     },
#                     {
#                         "state": "NE",
#                         "percent": 0.39
#                     },
#                     {
#                         "state": "WV",
#                         "percent": 0.28
#                     },
#                     {
#                         "state": "ME",
#                         "percent": 0.19
#                     },
#                     {
#                         "state": "NH",
#                         "percent": 0.16
#                     },
#                     {
#                         "state": "HI",
#                         "percent": 0.15
#                     },
#                     {
#                         "state": "MT",
#                         "percent": 0.13
#                     },
#                     {
#                         "state": "RI",
#                         "percent": 0.12
#                     },
#                     {
#                         "state": "AK",
#                         "percent": 0.11
#                     },
#                     {
#                         "state": "WY",
#                         "percent": 0.08
#                     },
#                     {
#                         "state": "SD",
#                         "percent": 0.07
#                     },
#                     {
#                         "state": "VT",
#                         "percent": 0.06
#                     },
#                     {
#                         "state": "DC",
#                         "percent": 0.04
#                     },
#                     {
#                         "state": "ND",
#                         "percent": 0.04
#                     }
#                 ],
#                 "delinquencies": {
#                     "del30Days": {
#                         "percent": 2.23
#                     },
#                     "del60Days": {
#                         "percent": 0.52
#                     },
#                     "del90Days": {
#                         "percent": 0.17
#                     },
#                     "del90PlusDays": {
#                         "percent": 0.63
#                     },
#                     "del120PlusDays": {
#                         "percent": 0.46
#                     }
#                 },
#                 "greenBondFlag": false,
#                 "highestRating": "AAA",
#                 "incomeCountry": "US",
#                 "issuerCountry": "US",
#                 "percentSecond": 0,
#                 "poolAgeMethod": "Calculated",
#                 "prepayEffDate": "2025-05-01",
#                 "seniorityType": "NA",
#                 "assetClassCode": "CO",
#                 "cgmiSectorCode": "MTGE",
#                 "collateralType": "GNMA",
#                 "fullPledgeFlag": false,
#                 "gpmPercentStep": 0,
#                 "incomeCountry3": "USA",
#                 "instrumentType": "NA",
#                 "issuerCountry2": "US",
#                 "issuerCountry3": "USA",
#                 "lowestRatingNF": "AA+",
#                 "poolIssuerName": "NA",
#                 "vPointCategory": "RP",
#                 "amortizedFHALTV": 63.4,
#                 "bloombergTicker": "GNSF 3.5 2013",
#                 "industrySubCode": "MT",
#                 "originationDate": "2013-05-01",
#                 "originationYear": 2013,
#                 "percent2To4Unit": 2.7,
#                 "percentHAMPMods": 0.9,
#                 "percentPurchase": 31.7,
#                 "percentStateHFA": 0.4,
#                 "poolOriginalWAM": 0,
#                 "preliminaryFlag": false,
#                 "redemptionValue": 100,
#                 "securitySubType": "MPGNMA",
#                 "dataQuartileList": [
#                     {
#                         "ltvlow": 17,
#                         "ltvhigh": 87,
#                         "loanSizeLow": 22000,
#                         "loanSizeHigh": 101000,
#                         "percentDTILow": 10,
#                         "creditScoreLow": 300,
#                         "percentDTIHigh": 24.4,
#                         "creditScoreHigh": 656,
#                         "originalLoanAgeLow": 0,
#                         "originationYearLow": 20101101,
#                         "originalLoanAgeHigh": 0,
#                         "originationYearHigh": 20130401
#                     },
#                     {
#                         "ltvlow": 87,
#                         "ltvhigh": 93,
#                         "loanSizeLow": 101000,
#                         "loanSizeHigh": 132000,
#                         "percentDTILow": 24.4,
#                         "creditScoreLow": 656,
#                         "percentDTIHigh": 34.9,
#                         "creditScoreHigh": 691,
#                         "originalLoanAgeLow": 0,
#                         "originationYearLow": 20130401,
#                         "originalLoanAgeHigh": 0,
#                         "originationYearHigh": 20130501
#                     },
#                     {
#                         "ltvlow": 93,
#                         "ltvhigh": 97,
#                         "loanSizeLow": 132000,
#                         "loanSizeHigh": 183000,
#                         "percentDTILow": 34.9,
#                         "creditScoreLow": 691,
#                         "percentDTIHigh": 43.6,
#                         "creditScoreHigh": 739,
#                         "originalLoanAgeLow": 0,
#                         "originationYearLow": 20130501,
#                         "originalLoanAgeHigh": 1,
#                         "originationYearHigh": 20130701
#                     },
#                     {
#                         "ltvlow": 97,
#                         "ltvhigh": 118,
#                         "loanSizeLow": 183000,
#                         "loanSizeHigh": 743000,
#                         "percentDTILow": 43.6,
#                         "creditScoreLow": 739,
#                         "percentDTIHigh": 65,
#                         "creditScoreHigh": 832,
#                         "originalLoanAgeLow": 1,
#                         "originationYearLow": 20130701,
#                         "originalLoanAgeHigh": 43,
#                         "originationYearHigh": 20141101
#                     }
#                 ],
#                 "gpmNumberOfSteps": 0,
#                 "percentHARPOwner": 0,
#                 "percentPrincipal": 100,
#                 "securityCalcType": "GNMA",
#                 "assetClassSubCode": "MBS",
#                 "forbearanceAmount": 0,
#                 "modifiedTimeStamp": "2025-05-13T19:08:00Z",
#                 "outstandingAmount": 1109.98,
#                 "parentDescription": "NA",
#                 "poolIsBalloonFlag": false,
#                 "prepaymentOptions": {
#                     "prepayType": [
#                         "CPR",
#                         "PSA",
#                         "VEC"
#                     ]
#                 },
#                 "reperformerMonths": 1,
#                 "dataPPMHistoryList": [
#                     {
#                         "prepayType": "PSA",
#                         "dataPPMHistoryDetailList": [
#                             {
#                                 "month": "1",
#                                 "prepayRate": 104.2558
#                             },
#                             {
#                                 "month": "3",
#                                 "prepayRate": 101.9675
#                             },
#                             {
#                                 "month": "6",
#                                 "prepayRate": 101.3512
#                             },
#                             {
#                                 "month": "12",
#                                 "prepayRate": 101.4048
#                             },
#                             {
#                                 "month": "24",
#                                 "prepayRate": 0
#                             }
#                         ]
#                     },
#                     {
#                         "prepayType": "CPR",
#                         "dataPPMHistoryDetailList": [
#                             {
#                                 "month": "1",
#                                 "prepayRate": 6.2554
#                             },
#                             {
#                                 "month": "3",
#                                 "prepayRate": 6.118
#                             },
#                             {
#                                 "month": "6",
#                                 "prepayRate": 6.0811
#                             },
#                             {
#                                 "month": "12",
#                                 "prepayRate": 6.0843
#                             },
#                             {
#                                 "month": "24",
#                                 "prepayRate": 0
#                             }
#                         ]
#                     }
#                 ],
#                 "daysToFirstPayment": 44,
#                 "issuerLowestRating": "NA",
#                 "issuerMiddleRating": "NA",
#                 "newCurrentLoanSize": 102989,
#                 "originationChannel": {
#                     "broker": 4.63,
#                     "retail": 62.09,
#                     "unknown": 0,
#                     "unspecified": 0,
#                     "correspondence": 33.27
#                 },
#                 "percentMultiFamily": 2.7,
#                 "percentRefiCashout": 5.8,
#                 "percentRegularMods": 3.5,
#                 "percentReperformer": 0.5,
#                 "relocationLoanFlag": false,
#                 "socialDensityScore": 0,
#                 "umbsfhlgPercentage": 0,
#                 "umbsfnmaPercentage": 0,
#                 "industryDescription": "Mortgage",
#                 "issuerHighestRating": "NA",
#                 "newOriginalLoanSize": 182018,
#                 "socialCriteriaShare": 0,
#                 "spreadAtOrigination": 22.4,
#                 "weightedAvgLoanSize": 102989,
#                 "poolOriginalLoanSize": 182018,
#                 "cgmiSectorDescription": "Mortgage",
#                 "expModelAvailableFlag": true,
#                 "fhfaImpliedCurrentLTV": 28,
#                 "percentRefiNonCashout": 58.1,
#                 "prepayPenaltySchedule": "0.000",
#                 "defaultHorizonPYMethod": "OAS Change",
#                 "industrySubDescription": "Mortgage Asset Backed",
#                 "actualPrepayHistoryList": {
#                     "date": "2025-07-01",
#                     "genericValue": 0.8893
#                 },
#                 "adjustedCurrentLoanSize": 102989,
#                 "forbearanceModification": 0,
#                 "percentTwoPlusBorrowers": 44,
#                 "poolAvgOriginalLoanTerm": 0,
#                 "adjustedOriginalLoanSize": 182007,
#                 "assetClassSubDescription": "Collateralized Asset Backed - Mortgage",
#                 "mortgageInsurancePremium": {
#                     "annual": {
#                         "va": 0,
#                         "fha": 0.794,
#                         "pih": 0,
#                         "rhs": 0.399
#                     },
#                     "upfront": {
#                         "va": 0.5,
#                         "fha": 0.69,
#                         "pih": 1,
#                         "rhs": 1.996
#                     }
#                 },
#                 "percentReperformerAndMod": 0.1,
#                 "reperformerMonthsForMods": 2,
#                 "dataPrepayModelSellerList": [
#                     {
#                         "seller": "HFAL",
#                         "percent": 0.07
#                     },
#                     {
#                         "seller": "HFUSM",
#                         "percent": 0.06
#                     },
#                     {
#                         "seller": "HFWA",
#                         "percent": 0.02
#                     }
#                 ],
#                 "originalLoanSizeRemaining": 150761,
#                 "percentFirstTimeHomeBuyer": 20.8,
#                 "current3rdPartyOrigination": 37.89,
#                 "adjustedSpreadAtOrigination": 22.4,
#                 "dataPrepayModelServicerList": [
#                     {
#                         "percent": 22.66,
#                         "servicer": "WELLS"
#                     },
#                     {
#                         "percent": 11.06,
#                         "servicer": "BCPOP"
#                     },
#                     {
#                         "percent": 10.88,
#                         "servicer": "NSTAR"
#                     },
#                     {
#                         "percent": 7.31,
#                         "servicer": "QUICK"
#                     },
#                     {
#                         "percent": 7.1,
#                         "servicer": "PENNY"
#                     },
#                     {
#                         "percent": 6.28,
#                         "servicer": "CARRG"
#                     },
#                     {
#                         "percent": 6.12,
#                         "servicer": "LAKEV"
#                     },
#                     {
#                         "percent": 5.43,
#                         "servicer": "USB"
#                     },
#                     {
#                         "percent": 4.26,
#                         "servicer": "FREE"
#                     },
#                     {
#                         "percent": 2.4,
#                         "servicer": "PNC"
#                     },
#                     {
#                         "percent": 1.33,
#                         "servicer": "MNTBK"
#                     },
#                     {
#                         "percent": 1.19,
#                         "servicer": "NWRES"
#                     },
#                     {
#                         "percent": 0.96,
#                         "servicer": "FIFTH"
#                     },
#                     {
#                         "percent": 0.75,
#                         "servicer": "DEPOT"
#                     },
#                     {
#                         "percent": 0.59,
#                         "servicer": "BOKF"
#                     },
#                     {
#                         "percent": 0.48,
#                         "servicer": "JPM"
#                     },
#                     {
#                         "percent": 0.47,
#                         "servicer": "TRUIS"
#                     },
#                     {
#                         "percent": 0.42,
#                         "servicer": "CITI"
#                     },
#                     {
#                         "percent": 0.38,
#                         "servicer": "GUILD"
#                     },
#                     {
#                         "percent": 0.21,
#                         "servicer": "REGNS"
#                     },
#                     {
#                         "percent": 0.2,
#                         "servicer": "CNTRL"
#                     },
#                     {
#                         "percent": 0.09,
#                         "servicer": "COLNL"
#                     },
#                     {
#                         "percent": 0.08,
#                         "servicer": "MNSRC"
#                     },
#                     {
#                         "percent": 0.07,
#                         "servicer": "HFAGY"
#                     },
#                     {
#                         "percent": 0.03,
#                         "servicer": "HOMBR"
#                     }
#                 ],
#                 "nonWeightedOriginalLoanSize": 0,
#                 "original3rdPartyOrigination": 0,
#                 "percentHARPDec2010Extension": 0,
#                 "percentHARPOneYearExtension": 0,
#                 "percentDownPaymentAssistance": 5.6,
#                 "percentAmortizedFHALTVUnder78": 95.4,
#                 "loanPerformanceImpliedCurrentLTV": 45.4,
#                 "reperformerMonthsForReperformers": 28
#             },
#             "ticker": "GNMA",
#             "country": "US",
#             "currency": "USD",
#             "identifier": "999818YT",
#             "description": "30-YR GNMA-2013 PROD",
#             "issuerTicker": "GNMA",
#             "maturityDate": "2041-12-01",
#             "securityType": "MORT",
#             "currentCoupon": 3.5,
#             "securitySubType": "MPGNMA"
#         }
#     ]
# }
