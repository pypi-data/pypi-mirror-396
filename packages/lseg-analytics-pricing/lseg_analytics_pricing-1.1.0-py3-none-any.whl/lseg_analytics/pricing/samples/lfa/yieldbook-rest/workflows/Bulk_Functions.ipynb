# %% [markdown]
# # Bulk Functions

# %% [markdown]
# This notebook demonstrates how to access and use the functinalities of **Bulk functions** which are part of our **YieldBook** module within LSEG Financial Analytics SDK.

# %% [markdown]
# ## Imports

# %% [markdown]
# Import the following necessary modules:
#
# - bulk_*** - libraries to access various bulk functionalities
# - get_results - get singular request results
# - get_csv_bulk_result - get a multiple request results at once
# - json - used for printout formating
# - time - used for response delay for call execution

# %%
from lseg_analytics.pricing.yield_book_rest import (
    bulk_compact_request,
    bulk_composite_request,
    BulkJsonInputItem,
    get_result,
    get_csv_bulk_result,
    get_job_status
)

import json as js

import pandas as pd
from io import StringIO

import time

# %% [markdown]
# ## Bulk Compact Request

# %% [markdown]
# A bulk request can be done in several ways, the first of which is using the Compact format where the user has to provide the following information:
# - path (str, required) - URL to which each individual request should be posted.i.e “/bond/py” for PY calculation.
#     - Currently supported paths:
#         - "/bond/indic" - Used for retrieval of Indicative data
#         - "/bond/py" - Used for retrieval of PriceYield data
#         - "/bond/cash-flow" - Used for retrieval of Cash Flow data
# - name_expr (str, optional) - Name of each request. This can be a valid JSON path expression, i.e “concat($.CUSIP,”_PY”)” will give each request the name CUSIP_PY. Name should be unique within a single job.
# - body (str, required) – POST body associated with the calculation. This is specific to each request type. Refer to individual calculation documentation for more details.
# - requests (List[Dict[str, Any]], required) – List of key value pairs. This values provided will be used to update corresponding variables in the body of the request.
# - params (Dict[str, Any], optional) - List of additional parameters for calculations that support it
# - create_job (bool, exclusively required) – Boolean with true and false values. Exclusively required with 'job' argument.
# - job (str, exclusively required) – Job reference. This can be of the form J-number or job name. Exclusively required with 'create_job'
# - name (str, optional) – User provided name.
# - pri (int, optional) – Priority for this request in the queue.
# - tags (List[str], optional) - List of tags used for subsequent addressing.

# %%
compact_job_name = "J-123456"

# bulk_compact_request
compact_response = bulk_compact_request(
                    path="/bond/py",
                    name_expr='concat($.CUSIP,"_PY")',
                    body=
                        {
                            "globalSettings": 
                                { 
                                    "pricingDate": "2023-03-31" 
                                }, 
                            "input": 
                                [ 
                                    { 
                                        "identifier.$": "$.id", 
                                        "idType": "cusip", 
                                        "level.$": "$.level", 
                                        "curve": 
                                            {
                                                "curveType": "SWAP"
                                            }, 
                                        "volatility": 
                                            {
                                                "type": "Default"
                                            }
                                    }
                                ]
                        },
                    requests=
                        [
                            {
                                "id": "31418DY55", 
                                "level": "96.578"
                            }, 
                            {   
                                "id": "31418D4J8", 
                                "level": "96.131"
                            }
                        ],
                    params={},
                    create_job=True,
                    job=compact_job_name,
                    name="BulkCompactRun",
                    pri=0
                )

print("Created following requests:")

# Iterate through all request ID's
for result in compact_response.results:
    print(result.id)
# Out:
# Created following requests:
# R-150615
# R-150616

# %% [markdown]
# ## Compact results retrieval and display

# %% [markdown]
# When a bulk operation is performed, the user is provided with a Request ID (visible in the previous output).
#
# These IDs can be used to obtain the results of the execution in one of two ways:
# - Singular - using get_results function with a single ID
# - Bulk - using get_csv_bulk_results function with a list of IDs

# %% [markdown]
# ### Singular Result

# %%
# Due to async nature, code Will perform the job status check 10 times, as result is not always ready instantly, with 10 second lapse between attempts
print("Calculating please wait...\n")

attempt = 1
max_attempts = 10
all_compact_results = []
 
while attempt < max_attempts:
        
        response = get_job_status(job_ref=compact_job_name)
        ok = response.get("okCount", None)
        pending = response.get("pendingCount", None)
        running = response.get("runningCount", None)
        if running == 0 and pending == 0 and ok != 0:
            print("Job is complete!\n")
            for result in compact_response.results:
                # Request results
                singular_compact_result = get_result(request_id_parameter=result.id)
                all_compact_results.append(singular_compact_result)
            break
        else:
              # If job is not yet done, repeat the loop
              print(response)
              time.sleep(10)
              attempt += 1

# Print results
print(js.dumps(all_compact_results, indent=4))
# Out:
# Calculating please wait...
#
# {'id': 'J-16437', 'name': 'J-123456', 'jobStatus': 'CLOSED', 'pendingCount': -2, 'runningCount': 2}
# Job is complete!
#
# [
#     {
#         "meta": {
#             "status": "DONE",
#             "requestId": "R-150615",
#             "timeStamp": "2025-12-03T07:43:28Z",
#             "responseType": "PY_CALC",
#             "resultsStatus": "ALL"
#         },
#         "results": [
#             {
#                 "py": {
#                     "oas": -127.9353,
#                     "wal": 3.066098,
#                     "dv01": 0.027898833,
#                     "cusip": "31418DY55",
#                     "price": 96.578,
#                     "yield": 2.663111,
#                     "ticker": "FNCN",
#                     "cmmType": 100,
#                     "eSpread": -125.1711,
#                     "pyLevel": "96.578",
#                     "zSpread": -120.395966,
#                     "duration": 2.886743,
#                     "ziSpread": -107.852348,
#                     "znSpread": -120.395966,
#                     "benchmark": "3 yr",
#                     "convexity": 0.1359,
#                     "curveDate": "2023-03-31",
#                     "curveType": "Swap",
#                     "fullPrice": 96.64466667,
#                     "modelCode": 2501,
#                     "prepayRate": 100.0,
#                     "prepayType": "VEC",
#                     "securityID": "31418DY5",
#                     "spreadDV01": 0.02815349,
#                     "tsyCurveID": "USDn0331",
#                     "accruedDays": 16,
#                     "description": "UMBS 10YR FIXED RATE",
#                     "grossSpread": -133.3566,
#                     "pricingDate": "2023-03-31",
#                     "swapCurveID": "SUSn331Q2",
#                     "currentYield": 1.553,
#                     "effectiveWAL": 3.0199,
#                     "maturityDate": "2030-11-01",
#                     "securityType": "MORT",
#                     "volModelType": "LMMSOFRFLAT",
#                     "yieldToWorst": 2.663111,
#                     "convexityCost": 9.8534,
#                     "currentCoupon": 1.5,
#                     "effectiveCV01": -0.001265207,
#                     "effectiveDV01": 0.027488077,
#                     "mortgageYield": 2.6485,
#                     "remainingTerm": 91,
#                     "effectiveYield": 2.7262,
#                     "marketSettings": {
#                         "settlementDate": "2023-04-17"
#                     },
#                     "settlementDate": "2023-04-17",
#                     "spreadDuration": 2.913093,
#                     "accruedInterest": 0.06666667,
#                     "annualizedYield": 2.681,
#                     "compoundingFreq": 2,
#                     "convexityEffect": -9.8534,
#                     "dataPpmProjList": [
#                         {
#                             "oneYear": 143.8745,
#                             "longTerm": 175.293,
#                             "oneMonth": 145.415,
#                             "sixMonth": 153.205,
#                             "prepayType": "PSA",
#                             "threeMonth": 158.127
#                         },
#                         {
#                             "oneYear": 8.2742,
#                             "longTerm": 10.3516,
#                             "oneMonth": 7.271,
#                             "sixMonth": 8.428,
#                             "prepayType": "CPR",
#                             "threeMonth": 8.223
#                         },
#                         {
#                             "oneYear": 8.516,
#                             "longTerm": 10.6675,
#                             "oneMonth": 7.278,
#                             "sixMonth": 8.544,
#                             "prepayType": "FwdCPR",
#                             "threeMonth": 8.263
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdCDR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRTurnover",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRCurtail",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefi",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiRateterm",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiCashout",
#                             "threeMonth": 0.0
#                         }
#                     ],
#                     "forwardMeasures": {
#                         "wal": 3.042215,
#                         "yield": 2.672049,
#                         "margin": -118.082
#                     },
#                     "spreadConvexity": 0.139,
#                     "yearsToMaturity": 7.5389,
#                     "economicExposure": 96.644667,
#                     "macaulayDuration": 2.9252,
#                     "spreadToActCurve": -115.0168,
#                     "spreadToTsyCurve": -115.5315,
#                     "yieldCurveMargin": -118.0819,
#                     "yieldToWorstCall": 2.663111,
#                     "effectiveDuration": 2.844241381,
#                     "spreadToBenchmark": -134.7566,
#                     "spreadToSwapCurve": -133.3566,
#                     "spreadToWorstCall": -133,
#                     "effectiveConvexity": -0.130913317,
#                     "moatsCurrentCoupon": 4.997,
#                     "optionModelCurveID": "SUSn331Q2",
#                     "yieldCurveDuration": 2.8442,
#                     "durationToWorstCase": 2.886743,
#                     "semiAnnualizedYield": 2.663111,
#                     "spreadToRFRSwapCurve": -103.6648,
#                     "yearsToFinalMaturity": 8.039,
#                     "spreadDurationTreasury": 2.913093,
#                     "fundedEffectiveDuration": 2.844241,
#                     "effectiveDurationPriceUp": 95.886844,
#                     "fundedEffectiveConvexity": -0.130913,
#                     "lastPrincipalPaymentDate": "2030-11-25",
#                     "effectiveDurationPriceDown": 97.261248
#                 },
#                 "securityID": "31418DY5"
#             }
#         ]
#     },
#     {
#         "meta": {
#             "status": "DONE",
#             "requestId": "R-150616",
#             "timeStamp": "2025-12-03T07:43:28Z",
#             "responseType": "PY_CALC",
#             "resultsStatus": "ALL"
#         },
#         "results": [
#             {
#                 "py": {
#                     "oas": -115.1572,
#                     "wal": 3.171015,
#                     "dv01": 0.028614176,
#                     "cusip": "31418D4J8",
#                     "price": 96.131,
#                     "yield": 2.781447,
#                     "ticker": "FNCN",
#                     "cmmType": 100,
#                     "eSpread": -112.2722,
#                     "pyLevel": "96.131",
#                     "zSpread": -106.816513,
#                     "duration": 2.974519,
#                     "ziSpread": -94.682549,
#                     "znSpread": -106.816513,
#                     "benchmark": "3 yr",
#                     "convexity": 0.1438,
#                     "curveDate": "2023-03-31",
#                     "curveType": "Swap",
#                     "fullPrice": 96.19766667,
#                     "modelCode": 2501,
#                     "prepayRate": 100.0,
#                     "prepayType": "VEC",
#                     "securityID": "31418D4J",
#                     "spreadDV01": 0.028807011,
#                     "tsyCurveID": "USDn0331",
#                     "accruedDays": 16,
#                     "description": "UMBS 10YR FIXED RATE",
#                     "grossSpread": -119.3008,
#                     "pricingDate": "2023-03-31",
#                     "swapCurveID": "SUSn331Q2",
#                     "currentYield": 1.56,
#                     "effectiveWAL": 3.1168,
#                     "maturityDate": "2031-02-01",
#                     "securityType": "MORT",
#                     "volModelType": "LMMSOFRFLAT",
#                     "yieldToWorst": 2.781447,
#                     "convexityCost": 10.4965,
#                     "currentCoupon": 1.5,
#                     "effectiveCV01": -0.001381181,
#                     "effectiveDV01": 0.028181799,
#                     "mortgageYield": 2.7655,
#                     "remainingTerm": 94,
#                     "effectiveYield": 2.8292,
#                     "marketSettings": {
#                         "settlementDate": "2023-04-17"
#                     },
#                     "settlementDate": "2023-04-17",
#                     "spreadDuration": 2.994564,
#                     "accruedInterest": 0.06666667,
#                     "annualizedYield": 2.801,
#                     "compoundingFreq": 2,
#                     "convexityEffect": -10.4965,
#                     "dataPpmProjList": [
#                         {
#                             "oneYear": 147.9697,
#                             "longTerm": 174.3862,
#                             "oneMonth": 160.849,
#                             "sixMonth": 167.777,
#                             "prepayType": "PSA",
#                             "threeMonth": 174.232
#                         },
#                         {
#                             "oneYear": 7.773,
#                             "longTerm": 9.9609,
#                             "oneMonth": 6.76,
#                             "sixMonth": 7.887,
#                             "prepayType": "CPR",
#                             "threeMonth": 7.667
#                         },
#                         {
#                             "oneYear": 8.0033,
#                             "longTerm": 10.2854,
#                             "oneMonth": 6.767,
#                             "sixMonth": 7.994,
#                             "prepayType": "FwdCPR",
#                             "threeMonth": 7.707
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdCDR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRTurnover",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRCurtail",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefi",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiRateterm",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiCashout",
#                             "threeMonth": 0.0
#                         }
#                     ],
#                     "forwardMeasures": {
#                         "wal": 3.145276,
#                         "yield": 2.791691,
#                         "margin": -104.661
#                     },
#                     "spreadConvexity": 0.146,
#                     "yearsToMaturity": 7.7889,
#                     "economicExposure": 96.197667,
#                     "macaulayDuration": 3.0159,
#                     "spreadToActCurve": -102.0725,
#                     "spreadToTsyCurve": -102.5641,
#                     "yieldCurveMargin": -104.6606,
#                     "yieldToWorstCall": 2.781447,
#                     "effectiveDuration": 2.929571867,
#                     "spreadToBenchmark": -122.923,
#                     "spreadToSwapCurve": -119.3008,
#                     "spreadToWorstCall": -119,
#                     "effectiveConvexity": -0.143577367,
#                     "moatsCurrentCoupon": 4.997,
#                     "optionModelCurveID": "SUSn331Q2",
#                     "yieldCurveDuration": 2.9296,
#                     "durationToWorstCase": 2.974519,
#                     "semiAnnualizedYield": 2.781447,
#                     "spreadToRFRSwapCurve": -89.6209,
#                     "yearsToFinalMaturity": 8.372,
#                     "spreadDurationTreasury": 2.994564,
#                     "fundedEffectiveDuration": 2.929572,
#                     "effectiveDurationPriceUp": 95.422139,
#                     "fundedEffectiveConvexity": -0.143577,
#                     "lastPrincipalPaymentDate": "2031-02-25",
#                     "effectiveDurationPriceDown": 96.831229
#                 },
#                 "securityID": "31418D4J"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ### Bulk Results

# %%
# Due to async nature, code Will perform the job status check 10 times, as result is not always ready instantly, with 10 second lapse between attempts
print("Calculating please wait...\n")

attempt = 1
max_attempts = 10
 
while attempt < max_attempts:
        
        response = get_job_status(job_ref=compact_job_name)
        ok = response.get("okCount", None)
        pending = response.get("pendingCount", None)
        running = response.get("runningCount", None)
        if running == 0 and pending == 0 and ok != 0:
            print("Job is complete! \n")
            bulk_compact_result_csv = get_csv_bulk_result(
                                                ids=[result.id for result in compact_response.results], 
                                                fields=["CUSIP:py.cusip", "Yield:py.yield", "OAS:py.oas"]
                                            )
            break
        else:
              # If job is not yet done, repeat the loop
              print(response)
              time.sleep(10)
              attempt += 1

# Print Bulk singular result
df = pd.read_csv(StringIO(bulk_compact_result_csv))
print(df)
# Out:
# Calculating please wait...
#
# Job is complete!
#
#        CUSIP     Yield       OAS
# 0  31418DY55  2.663111 -127.9353
# 1  31418D4J8  2.781447 -115.1572

# %% [markdown]
# ## Bulk Composite Request

# %% [markdown]
# The second way to execute a bulk request is in using the Composite format, where a user has to provide the following information:
#
# - requests (List[BulkJsonInputItem], required) – List of BulkJsonInputItem items. Please consult documentation for
# - create_job (bool, exclusively required) – Boolean with true and false values. Exclusively required with 'job' argument.
# - job (str, exclusively required) – Job reference. This can be of the form J-number or job name. Exclusively required with 'create_job'
# - name (str, optional) – User provided name.
# - pri (int, optional) – Priority for this request in the queue
#
# With the Composite function, unlike the Compact function, the user can set the input valus for each individual instrument.

# %%
composite_job_name = "J-654321"

# bulk_composite_request
composite_response = bulk_composite_request(
                        requests=[
                            BulkJsonInputItem(
                                path="/bond/py",
                                body=
                                    {
                                        "globalSettings": 
                                            { 
                                                "pricingDate": "2023-03-31"
                                            },
                                        "input": 
                                            [ 
                                                {
                                                    "identifier": "31418DY55",
                                                    "idType": "cusip", 
                                                    "level": "109.706", 
                                                    "curve": 
                                                        {
                                                            "curveType": "SWAP"
                                                        }, 
                                                    "volatility": 
                                                        {
                                                            "type": "Default" 
                                                        }
                                                },                                                
                                                {
                                                    "identifier": "31418D4J8",
                                                    "idType": "cusip", 
                                                    "level": "96.131", 
                                                    "curve": 
                                                        {
                                                            "curveType": "SWAP"
                                                        }, 
                                                    "volatility": 
                                                        {
                                                            "type": "Default" 
                                                        }
                                                }
                                            ]
                                    },
                            )
                        ],
                        create_job=True,
                        job=composite_job_name
                    )

print("Created following requests:")

# Iterate through all request ID's
for result in composite_response.results:
    print(result.id)
# Out:
# Created following requests:
# R-150618

# %% [markdown]
# ## Composite results retrieval and display

# %% [markdown]
# In the Composite bulk function context, the user is presented with a single request ID, which can be used with both result retrieval functions, either for a single result or for bulk results with multiple request IDs.

# %% [markdown]
# ### Bulk result retrieval - get_result()

# %%
# Due to async nature, code Will perform the job status check 10 times, as result is not always ready instantly, with 10 second lapse between attempts
print("Calculating please wait...\n")

attempt = 1
max_attempts = 10
all_composite_results = []
 
while attempt < max_attempts:
        
        response = get_job_status(job_ref=composite_job_name)
        ok = response.get("okCount", None)
        pending = response.get("pendingCount", None)
        running = response.get("runningCount", None)
        if running == 0 and pending == 0 and ok != 0:
            print("Job is complete!\n")
            for result in composite_response.results:
                # Request results
                singular_composite_result = get_result(request_id_parameter=result.id)
                all_composite_results.append(singular_composite_result)
            break
        else:
              # If job is not yet done, repeat the loop
              print(response)
              time.sleep(10)
              attempt += 1

# Print results
print(js.dumps(all_composite_results, indent=4))
# Out:
# Calculating please wait...
#
# {'id': 'J-16438', 'name': 'J-654321', 'jobStatus': 'CLOSED', 'requestCount': 1, 'pendingCount': 0, 'runningCount': 1, 'okCount': 0, 'errorCount': 0, 'abortedCount': 0, 'skippedCount': 0}
# Job is complete!
#
# [
#     {
#         "meta": {
#             "status": "DONE",
#             "requestId": "R-150618",
#             "timeStamp": "2025-12-03T07:43:41Z",
#             "responseType": "PY_CALC",
#             "resultsStatus": "ALL"
#         },
#         "results": [
#             {
#                 "py": {
#                     "oas": -548.3548,
#                     "wal": 3.066098,
#                     "dv01": 0.034245618,
#                     "cusip": "31418DY55",
#                     "price": 109.706,
#                     "yield": -1.580365,
#                     "ticker": "FNCN",
#                     "cmmType": 100,
#                     "eSpread": -540.201,
#                     "pyLevel": "109.706",
#                     "zSpread": -541.84021,
#                     "duration": 3.119685,
#                     "ziSpread": -529.930725,
#                     "znSpread": -541.84021,
#                     "benchmark": "3 yr",
#                     "convexity": 0.1546,
#                     "curveDate": "2023-03-31",
#                     "curveType": "Swap",
#                     "fullPrice": 109.77266667,
#                     "modelCode": 2501,
#                     "prepayRate": 100.0,
#                     "prepayType": "VEC",
#                     "securityID": "31418DY5",
#                     "spreadDV01": 0.03457541,
#                     "tsyCurveID": "USDn0331",
#                     "accruedDays": 16,
#                     "description": "UMBS 10YR FIXED RATE",
#                     "grossSpread": -557.7042,
#                     "pricingDate": "2023-03-31",
#                     "swapCurveID": "SUSn331Q2",
#                     "currentYield": 1.367,
#                     "effectiveWAL": 3.0199,
#                     "maturityDate": "2030-11-01",
#                     "securityType": "MORT",
#                     "volModelType": "LMMSOFRFLAT",
#                     "yieldToWorst": -1.580365,
#                     "convexityCost": 13.8919,
#                     "currentCoupon": 1.5,
#                     "effectiveCV01": -0.002082689,
#                     "effectiveDV01": 0.027260458,
#                     "mortgageYield": -1.5856,
#                     "remainingTerm": 91,
#                     "effectiveYield": -1.478,
#                     "marketSettings": {
#                         "settlementDate": "2023-04-17"
#                     },
#                     "settlementDate": "2023-04-17",
#                     "spreadDuration": 3.149729,
#                     "accruedInterest": 0.06666667,
#                     "annualizedYield": -1.574,
#                     "compoundingFreq": 2,
#                     "convexityEffect": -13.8919,
#                     "dataPpmProjList": [
#                         {
#                             "oneYear": 143.8745,
#                             "longTerm": 175.293,
#                             "oneMonth": 145.415,
#                             "sixMonth": 153.205,
#                             "prepayType": "PSA",
#                             "threeMonth": 158.127
#                         },
#                         {
#                             "oneYear": 8.2742,
#                             "longTerm": 10.3516,
#                             "oneMonth": 7.271,
#                             "sixMonth": 8.428,
#                             "prepayType": "CPR",
#                             "threeMonth": 8.223
#                         },
#                         {
#                             "oneYear": 8.516,
#                             "longTerm": 10.6675,
#                             "oneMonth": 7.278,
#                             "sixMonth": 8.544,
#                             "prepayType": "FwdCPR",
#                             "threeMonth": 8.263
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdCDR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRTurnover",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRCurtail",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefi",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiRateterm",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiCashout",
#                             "threeMonth": 0.0
#                         }
#                     ],
#                     "forwardMeasures": {
#                         "wal": 3.042215,
#                         "yield": -1.603339,
#                         "margin": -534.463
#                     },
#                     "spreadConvexity": 0.158,
#                     "yearsToMaturity": 7.5389,
#                     "economicExposure": 109.772667,
#                     "macaulayDuration": 3.095,
#                     "spreadToActCurve": -539.3644,
#                     "spreadToTsyCurve": -539.8791,
#                     "yieldCurveMargin": -534.4628,
#                     "yieldToWorstCall": -1.580365,
#                     "effectiveDuration": 2.483355761,
#                     "spreadToBenchmark": -559.1042,
#                     "spreadToSwapCurve": -557.7042,
#                     "spreadToWorstCall": -558,
#                     "effectiveConvexity": -0.189727455,
#                     "moatsCurrentCoupon": 4.997,
#                     "optionModelCurveID": "SUSn331Q2",
#                     "yieldCurveDuration": 2.4834,
#                     "durationToWorstCase": 3.119685,
#                     "semiAnnualizedYield": -1.580365,
#                     "spreadToRFRSwapCurve": -528.0124,
#                     "yearsToFinalMaturity": 8.039,
#                     "spreadDurationTreasury": 3.149729,
#                     "fundedEffectiveDuration": 2.483356,
#                     "effectiveDurationPriceUp": 109.01798,
#                     "fundedEffectiveConvexity": -0.189727,
#                     "lastPrincipalPaymentDate": "2030-11-25",
#                     "effectiveDurationPriceDown": 110.381003
#                 },
#                 "securityID": "31418DY5"
#             },
#             {
#                 "py": {
#                     "oas": -115.1572,
#                     "wal": 3.171015,
#                     "dv01": 0.028614176,
#                     "cusip": "31418D4J8",
#                     "price": 96.131,
#                     "yield": 2.781447,
#                     "ticker": "FNCN",
#                     "cmmType": 100,
#                     "eSpread": -112.2722,
#                     "pyLevel": "96.131",
#                     "zSpread": -106.816513,
#                     "duration": 2.974519,
#                     "ziSpread": -94.682549,
#                     "znSpread": -106.816513,
#                     "benchmark": "3 yr",
#                     "convexity": 0.1438,
#                     "curveDate": "2023-03-31",
#                     "curveType": "Swap",
#                     "fullPrice": 96.19766667,
#                     "modelCode": 2501,
#                     "prepayRate": 100.0,
#                     "prepayType": "VEC",
#                     "securityID": "31418D4J",
#                     "spreadDV01": 0.028807011,
#                     "tsyCurveID": "USDn0331",
#                     "accruedDays": 16,
#                     "description": "UMBS 10YR FIXED RATE",
#                     "grossSpread": -119.3008,
#                     "pricingDate": "2023-03-31",
#                     "swapCurveID": "SUSn331Q2",
#                     "currentYield": 1.56,
#                     "effectiveWAL": 3.1168,
#                     "maturityDate": "2031-02-01",
#                     "securityType": "MORT",
#                     "volModelType": "LMMSOFRFLAT",
#                     "yieldToWorst": 2.781447,
#                     "convexityCost": 10.4965,
#                     "currentCoupon": 1.5,
#                     "effectiveCV01": -0.001381181,
#                     "effectiveDV01": 0.028181799,
#                     "mortgageYield": 2.7655,
#                     "remainingTerm": 94,
#                     "effectiveYield": 2.8292,
#                     "marketSettings": {
#                         "settlementDate": "2023-04-17"
#                     },
#                     "settlementDate": "2023-04-17",
#                     "spreadDuration": 2.994564,
#                     "accruedInterest": 0.06666667,
#                     "annualizedYield": 2.801,
#                     "compoundingFreq": 2,
#                     "convexityEffect": -10.4965,
#                     "dataPpmProjList": [
#                         {
#                             "oneYear": 147.9697,
#                             "longTerm": 174.3862,
#                             "oneMonth": 160.849,
#                             "sixMonth": 167.777,
#                             "prepayType": "PSA",
#                             "threeMonth": 174.232
#                         },
#                         {
#                             "oneYear": 7.773,
#                             "longTerm": 9.9609,
#                             "oneMonth": 6.76,
#                             "sixMonth": 7.887,
#                             "prepayType": "CPR",
#                             "threeMonth": 7.667
#                         },
#                         {
#                             "oneYear": 8.0033,
#                             "longTerm": 10.2854,
#                             "oneMonth": 6.767,
#                             "sixMonth": 7.994,
#                             "prepayType": "FwdCPR",
#                             "threeMonth": 7.707
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdCDR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPR",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRTurnover",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRCurtail",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefi",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiRateterm",
#                             "threeMonth": 0.0
#                         },
#                         {
#                             "oneYear": 0.0,
#                             "longTerm": 0.0,
#                             "oneMonth": 0.0,
#                             "sixMonth": 0.0,
#                             "prepayType": "FwdVPRRefiCashout",
#                             "threeMonth": 0.0
#                         }
#                     ],
#                     "forwardMeasures": {
#                         "wal": 3.145276,
#                         "yield": 2.791691,
#                         "margin": -104.661
#                     },
#                     "spreadConvexity": 0.146,
#                     "yearsToMaturity": 7.7889,
#                     "economicExposure": 96.197667,
#                     "macaulayDuration": 3.0159,
#                     "spreadToActCurve": -102.0725,
#                     "spreadToTsyCurve": -102.5641,
#                     "yieldCurveMargin": -104.6606,
#                     "yieldToWorstCall": 2.781447,
#                     "effectiveDuration": 2.929571867,
#                     "spreadToBenchmark": -122.923,
#                     "spreadToSwapCurve": -119.3008,
#                     "spreadToWorstCall": -119,
#                     "effectiveConvexity": -0.143577367,
#                     "moatsCurrentCoupon": 4.997,
#                     "optionModelCurveID": "SUSn331Q2",
#                     "yieldCurveDuration": 2.9296,
#                     "durationToWorstCase": 2.974519,
#                     "semiAnnualizedYield": 2.781447,
#                     "spreadToRFRSwapCurve": -89.6209,
#                     "yearsToFinalMaturity": 8.372,
#                     "spreadDurationTreasury": 2.994564,
#                     "fundedEffectiveDuration": 2.929572,
#                     "effectiveDurationPriceUp": 95.422139,
#                     "fundedEffectiveConvexity": -0.143577,
#                     "lastPrincipalPaymentDate": "2031-02-25",
#                     "effectiveDurationPriceDown": 96.831229
#                 },
#                 "securityID": "31418D4J"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ### Bulk result retrieval - get_csv_bulk_result()

# %%
# Due to async nature, code Will perform the job status check 10 times, as result is not always ready instantly, with 10 second lapse between attempts
print("Calculating please wait...\n")

attempt = 1
max_attempts = 10
all_composite_results = []
 
while attempt < max_attempts:
        
        response = get_job_status(job_ref=composite_job_name)
        ok = response.get("okCount", None)
        pending = response.get("pendingCount", None)
        running = response.get("runningCount", None)
        if running == 0 and pending == 0 and ok != 0:
            print("Job is complete!\n")
            bulk_composite_result_csv = get_csv_bulk_result(
                                                    ids=[result.id for result in composite_response.results], 
                                                    fields=["CUSIP:py.cusip", "Yield:py.yield", "OAS:py.oas"]
                                                )
            break
        else:
              # If job is not yet done, repeat the loop
              print(response)
              time.sleep(10)
              attempt += 1

# Print Bulk result
df = pd.read_csv(StringIO(bulk_composite_result_csv))
print(df)
# Out:
# Calculating please wait...
#
# Job is complete!
#
#        CUSIP     Yield       OAS
# 0  31418DY55 -1.580365 -548.3548
# 1  31418D4J8  2.781447 -115.1572
