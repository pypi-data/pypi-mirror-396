# %% [markdown]
# # FX Forwards Fundamentals

# %% [markdown]
# This notebook demonstrates how to access and use the functionalities of **FX Forwards** which are part of our **QPS** module within LSEG Financial Analytics SDK.

# %% [markdown]
# ## Imports

# %% [markdown]
# Import the following necessary modules:

# %%
from lseg_analytics.pricing.instruments.fx_forwards import (
    FxForward,
    FxForwardDefinition,
    FxRate,
    FxPricingParameters,
    FxForwardCurveChoice,
    MarketData,
    FxForwardDefinition,
    FxForwardDefinitionInstrument,
    price,
    value,
    search,
    load,
    delete
)

from lseg_analytics.pricing.common import(
    AdjustableDate,
    RelativeAdjustableDate,
    AdjustableDate, 
    ReferenceDate
)

import json

from datetime import date

# %% [markdown]
# ## Creating an FX Forward definition
#
# Create a 1Y FxForward on EURUSD

# %%
fxforward_definition = FxForwardDefinitionInstrument(
    definition=FxForwardDefinition(
        base_currency="EUR",
        quoted_currency="USD",
        rate=FxRate(value=1.16),
        end_date=RelativeAdjustableDate(
            tenor="1Y", reference_date=ReferenceDate.START_DATE
        )
    )
)

print(json.dumps(fxforward_definition.as_dict(), indent=4))
# Out:
# {
#     "definition": {
#         "baseCurrency": "EUR",
#         "quotedCurrency": "USD",
#         "rate": {
#             "value": 1.16
#         },
#         "endDate": {
#             "dateType": "RelativeAdjustableDate",
#             "tenor": "1Y",
#             "referenceDate": "StartDate"
#         }
#     }
# }

# %% [markdown]
# ## Pricing an FX Forward
#
# Price the FxForward at specific valuation date. Price method is usually used to get outright and swap points, independently of the fxRate set in FX Forward.

# %%
params = FxPricingParameters(
    valuation_date="2025-10-30",
)

fx_forward_price = price(definitions=[fxforward_definition], pricing_preferences=params, return_market_data=False)

print(json.dumps(fx_forward_price.as_dict(), indent=4))
print("FX swap points EURUSD - Bid:", fx_forward_price.analytics[0].pricing_analysis.fx_swaps_ccy1_ccy2.bid)
print("FX swap points EURUSD - Ask:", fx_forward_price.analytics[0].pricing_analysis.fx_swaps_ccy1_ccy2.ask)
print("FX outrights EURUSD - Bid:", fx_forward_price.analytics[0].pricing_analysis.fx_outright_ccy1_ccy2.bid)
print("FX outrights EURUSD - Ask:", fx_forward_price.analytics[0].pricing_analysis.fx_outright_ccy1_ccy2.ask)
# Out:
# {
#     "definitions": [
#         {
#             "definition": {
#                 "quotedCurrency": "USD",
#                 "baseCurrency": "EUR",
#                 "dealAmount": 1000000.0,
#                 "rate": {
#                     "value": 1.16,
#                     "scalingFactor": 1.0,
#                     "ratePrecision": 4
#                 },
#                 "endDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "1Y",
#                     "referenceDate": "StartDate"
#                 }
#             }
#         }
#     ],
#     "pricingPreferences": {
#         "valuationDate": "2025-10-30"
#     },
#     "analytics": [
#         {
#             "description": {
#                 "valuationDate": "2025-10-30",
#                 "startDate": {
#                     "unAdjusted": "2025-11-03",
#                     "adjusted": "2025-11-03",
#                     "dateMovingConvention": "NextBusinessDay"
#                 },
#                 "endDate": {
#                     "unAdjusted": "2026-11-03",
#                     "adjusted": "2026-11-03",
#                     "dateMovingConvention": "NextBusinessDay",
#                     "referenceDate": "StartDate",
#                     "tenor": "1Y"
#                 }
#             },
#             "pricingAnalysis": {
#                 "fxSwapsCcy1": {
#                     "bid": 199.24999999999972,
#                     "ask": 204.37000000000037
#                 },
#                 "fxSwapsCcy2": {
#                     "bid": 0.0,
#                     "ask": 0.0
#                 },
#                 "fxSwapsCcy1Ccy2": {
#                     "bid": 199.24999999999972,
#                     "ask": 204.37000000000037
#                 },
#                 "fxOutrightCcy1Ccy2": {
#                     "bid": 1.176425,
#                     "ask": 1.177037
#                 },
#                 "rate": 1.16,
#                 "fxSpot": {
#                     "bid": 1.1565,
#                     "ask": 1.1566
#                 },
#                 "dealAmount": 1000000.0,
#                 "contraAmount": 1160000.0
#             },
#             "greeks": {
#                 "deltaPercent": 97.9419580978423,
#                 "deltaAmountInDealCcy": 965493.994748987,
#                 "deltaAmountInContraCcy": 979419.580978423
#             }
#         }
#     ]
# }
# FX swap points EURUSD - Bid: 199.24999999999972
# FX swap points EURUSD - Ask: 204.37000000000037
# FX outrights EURUSD - Bid: 1.176425
# FX outrights EURUSD - Ask: 1.177037

# %% [markdown]
# ## Valuing an FX Forward
#
# Compute the FxForward market value at specific valuation date. The market value depends on the FxRate set in the FxForward

# %%
params = FxPricingParameters(
    valuation_date="2024-01-11",
)

fx_forward_value = value(definitions=[fxforward_definition], pricing_preferences=params, return_market_data=False)

print(json.dumps(fx_forward_value.as_dict(), indent=4))
print("MarketValueInDealCcy:", fx_forward_value.analytics[0].valuation.market_value_in_deal_ccy)
print("MarketValueInContraCcy:", fx_forward_value.analytics[0].valuation.market_value_in_contra_ccy)
# Out:
# {
#     "definitions": [
#         {
#             "definition": {
#                 "quotedCurrency": "USD",
#                 "baseCurrency": "EUR",
#                 "dealAmount": 1000000.0,
#                 "rate": {
#                     "value": 1.16,
#                     "scalingFactor": 1.0,
#                     "ratePrecision": 4
#                 },
#                 "endDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "1Y",
#                     "referenceDate": "StartDate"
#                 }
#             }
#         }
#     ],
#     "pricingPreferences": {
#         "valuationDate": "2024-01-11"
#     },
#     "analytics": [
#         {
#             "description": {
#                 "valuationDate": "2024-01-11",
#                 "startDate": {
#                     "unAdjusted": "2024-01-16",
#                     "adjusted": "2024-01-16",
#                     "dateMovingConvention": "NextBusinessDay"
#                 },
#                 "endDate": {
#                     "unAdjusted": "2025-01-16",
#                     "adjusted": "2025-01-16",
#                     "dateMovingConvention": "NextBusinessDay",
#                     "referenceDate": "StartDate",
#                     "tenor": "1Y"
#                 }
#             },
#             "valuation": {
#                 "discountFactor": 0.964857136846359,
#                 "marketValueInDealCcy": -39788.1745820582,
#                 "marketValueInContraCcy": -43823.068093755
#             },
#             "greeks": {
#                 "deltaPercent": 96.4857136846359,
#                 "deltaAmountInDealCcy": 1004667.06947428,
#                 "deltaAmountInContraCcy": 964857.136846359
#             }
#         }
#     ]
# }
# MarketValueInDealCcy: -39788.1745820582
# MarketValueInContraCcy: -43823.068093755

# %% [markdown]
# ## Create,save, price and delete an FxForward
#
# Creating and saving an FxForward is usefull to share information or price the instrument later

# %%
fx_forward = FxForward(
    FxForwardDefinition(
        base_currency="EUR",
        quoted_currency="USD",
        end_date=RelativeAdjustableDate(
            tenor="1Y", reference_date=ReferenceDate.START_DATE
        ),
    )
)

fx_forward.save(name='my_fx_Forward_pricing_test', space='HOME')

print(json.dumps(fx_forward_price.as_dict(), indent=4))
# Out:
# {
#     "definitions": [
#         {
#             "definition": {
#                 "quotedCurrency": "USD",
#                 "baseCurrency": "EUR",
#                 "dealAmount": 1000000.0,
#                 "rate": {
#                     "value": 1.16,
#                     "scalingFactor": 1.0,
#                     "ratePrecision": 4
#                 },
#                 "endDate": {
#                     "dateType": "RelativeAdjustableDate",
#                     "tenor": "1Y",
#                     "referenceDate": "StartDate"
#                 }
#             }
#         }
#     ],
#     "pricingPreferences": {
#         "valuationDate": "2025-10-30"
#     },
#     "analytics": [
#         {
#             "description": {
#                 "valuationDate": "2025-10-30",
#                 "startDate": {
#                     "unAdjusted": "2025-11-03",
#                     "adjusted": "2025-11-03",
#                     "dateMovingConvention": "NextBusinessDay"
#                 },
#                 "endDate": {
#                     "unAdjusted": "2026-11-03",
#                     "adjusted": "2026-11-03",
#                     "dateMovingConvention": "NextBusinessDay",
#                     "referenceDate": "StartDate",
#                     "tenor": "1Y"
#                 }
#             },
#             "pricingAnalysis": {
#                 "fxSwapsCcy1": {
#                     "bid": 199.24999999999972,
#                     "ask": 204.37000000000037
#                 },
#                 "fxSwapsCcy2": {
#                     "bid": 0.0,
#                     "ask": 0.0
#                 },
#                 "fxSwapsCcy1Ccy2": {
#                     "bid": 199.24999999999972,
#                     "ask": 204.37000000000037
#                 },
#                 "fxOutrightCcy1Ccy2": {
#                     "bid": 1.176425,
#                     "ask": 1.177037
#                 },
#                 "rate": 1.16,
#                 "fxSpot": {
#                     "bid": 1.1565,
#                     "ask": 1.1566
#                 },
#                 "dealAmount": 1000000.0,
#                 "contraAmount": 1160000.0
#             },
#             "greeks": {
#                 "deltaPercent": 97.9419580978423,
#                 "deltaAmountInDealCcy": 965493.994748987,
#                 "deltaAmountInContraCcy": 979419.580978423
#             }
#         }
#     ]
# }

# %% [markdown]
# ## Load an existing FxForward from the platform and price it.

# %%
loaded_forward = load(name='my_fx_Forward_pricing_test', space='HOME')
print(loaded_forward)

loaded_fx_forward_price = loaded_forward.price(
    pricing_preferences=FxPricingParameters(
        valuation_date="2025-10-11",
    )
)

print(json.dumps(loaded_fx_forward_price.as_dict(), indent=4))

delete(name='my_fx_Forward_pricing_test', space='HOME')
# Out:
# <FxForward space='HOME' name='my_fx_Forward_pricing_test' ff8e6d18‥>
# {
#     "resource": {
#         "type": "FxForward",
#         "id": "ff8e6d18-dcf4-447c-a0a1-fb350622e7d3",
#         "location": {
#             "space": "HOME",
#             "name": "my_fx_Forward_pricing_test"
#         },
#         "description": {
#             "tags": []
#         },
#         "definition": {
#             "quotedCurrency": "USD",
#             "baseCurrency": "EUR",
#             "dealAmount": 1000000.0,
#             "endDate": {
#                 "dateType": "RelativeAdjustableDate",
#                 "tenor": "1Y",
#                 "referenceDate": "StartDate"
#             }
#         }
#     },
#     "pricingPreferences": {
#         "valuationDate": "2025-10-11"
#     },
#     "analytics": {
#         "description": {
#             "valuationDate": "2025-10-11",
#             "startDate": {
#                 "unAdjusted": "2025-10-14",
#                 "adjusted": "2025-10-14",
#                 "dateMovingConvention": "NextBusinessDay"
#             },
#             "endDate": {
#                 "unAdjusted": "2026-10-14",
#                 "adjusted": "2026-10-14",
#                 "dateMovingConvention": "NextBusinessDay",
#                 "referenceDate": "StartDate",
#                 "tenor": "1Y"
#             }
#         },
#         "pricingAnalysis": {
#             "fxSwapsCcy1": {
#                 "bid": 192.09999999999948,
#                 "ask": 198.10000000000105
#             },
#             "fxSwapsCcy2": {
#                 "bid": 0.0,
#                 "ask": 0.0
#             },
#             "fxSwapsCcy1Ccy2": {
#                 "bid": 192.09999999999948,
#                 "ask": 198.10000000000105
#             },
#             "fxOutrightCcy1Ccy2": {
#                 "bid": 1.18101,
#                 "ask": 1.18201
#             },
#             "rate": 1.18201,
#             "fxSpot": {
#                 "bid": 1.1618,
#                 "ask": 1.1622
#             },
#             "dealAmount": 1000000.0,
#             "contraAmount": 1182010.0
#         },
#         "greeks": {
#             "deltaPercent": 97.9621824536288,
#             "deltaAmountInDealCcy": 980036.388028995,
#             "deltaAmountInContraCcy": 979621.824536288
#         }
#     }
# }
# True

# %% [markdown]
# ## Price a FX Forward Forward
#
# Below is the prcing of a more complex case of FX Forward:
# - use USD as reference currency
# - define start date and end date using
# - display market data used for pricing

# %%
fxforward_definition = FxForwardDefinitionInstrument(
    definition=FxForwardDefinition(
        base_currency="EUR",
        quoted_currency="CHF",
        start_date=AdjustableDate(date="2030-01-01"),
        end_date=AdjustableDate(date="2031-01-01"),
    )
)

params = FxPricingParameters(
    valuation_date="2025-10-30",
    ignore_reference_currency_holidays=True, 
    reference_currency="USD",
)

fx_forward_price = price(definitions=[fxforward_definition], pricing_preferences=params, return_market_data=True)

print(json.dumps(fx_forward_price.as_dict(), indent=4))
# Out:
# {
#     "definitions": [
#         {
#             "definition": {
#                 "quotedCurrency": "CHF",
#                 "baseCurrency": "EUR",
#                 "dealAmount": 1000000.0,
#                 "startDate": {
#                     "dateType": "AdjustableDate",
#                     "date": "2030-01-01"
#                 },
#                 "endDate": {
#                     "dateType": "AdjustableDate",
#                     "date": "2031-01-01"
#                 }
#             }
#         }
#     ],
#     "pricingPreferences": {
#         "ignoreReferenceCurrencyHolidays": true,
#         "referenceCurrency": "USD",
#         "valuationDate": "2025-10-30"
#     },
#     "analytics": [
#         {
#             "description": {
#                 "valuationDate": "2025-10-30",
#                 "startDate": {
#                     "unAdjusted": "2030-01-01",
#                     "adjusted": "2030-01-03",
#                     "dateMovingConvention": "NextBusinessDay",
#                     "date": "2030-01-01"
#                 },
#                 "endDate": {
#                     "unAdjusted": "2031-01-01",
#                     "adjusted": "2031-01-03",
#                     "dateMovingConvention": "NextBusinessDay",
#                     "date": "2031-01-01"
#                 }
#             },
#             "pricingAnalysis": {
#                 "fxSwapsCcy1": {
#                     "bid": 125.58956043957005,
#                     "ask": 158.60796703296364
#                 },
#                 "fxSwapsCcy2": {
#                     "bid": -255.28296703296292,
#                     "ask": -204.64835164835313
#                 },
#                 "fxSwapsCcy1Ccy2": {
#                     "bid": -228.26634093496057,
#                     "ask": -142.97436849173062
#                 },
#                 "fxOutrightCcy1Ccy2": {
#                     "bid": 0.826500850982672,
#                     "ask": 0.8316610208854001
#                 },
#                 "rate": 0.8316610208854,
#                 "fxSpot": {
#                     "bid": 0.9271660500000001,
#                     "ask": 0.92782452
#                 },
#                 "dealAmount": 1000000.0,
#                 "contraAmount": 831661.0208854
#             },
#             "greeks": {
#                 "deltaPercent": 97.4020982459233,
#                 "deltaAmountInDealCcy": 977052.118226846,
#                 "deltaAmountInContraCcy": 974020.982459233
#             }
#         }
#     ],
#     "marketData": {
#         "fxForwardCurves": [
#             {
#                 "curve": {
#                     "fxType": "Outright",
#                     "points": [
#                         {
#                             "date": "2025-11-04",
#                             "value": 1.15661705
#                         },
#                         {
#                             "date": "2025-11-10",
#                             "value": 1.15701
#                         },
#                         {
#                             "date": "2025-11-17",
#                             "value": 1.157461
#                         },
#                         {
#                             "date": "2025-11-24",
#                             "value": 1.1579125000000001
#                         },
#                         {
#                             "date": "2025-12-03",
#                             "value": 1.158511
#                         },
#                         {
#                             "date": "2026-01-05",
#                             "value": 1.160691
#                         },
#                         {
#                             "date": "2026-02-03",
#                             "value": 1.162409
#                         },
#                         {
#                             "date": "2026-03-03",
#                             "value": 1.164021
#                         },
#                         {
#                             "date": "2026-04-07",
#                             "value": 1.16601
#                         },
#                         {
#                             "date": "2026-05-04",
#                             "value": 1.1675135
#                         },
#                         {
#                             "date": "2026-06-03",
#                             "value": 1.1691525
#                         },
#                         {
#                             "date": "2026-07-03",
#                             "value": 1.1707610000000002
#                         },
#                         {
#                             "date": "2026-08-03",
#                             "value": 1.172325
#                         },
#                         {
#                             "date": "2026-09-03",
#                             "value": 1.1738215
#                         },
#                         {
#                             "date": "2026-10-05",
#                             "value": 1.1753295000000001
#                         },
#                         {
#                             "date": "2026-11-03",
#                             "value": 1.1767310000000002
#                         },
#                         {
#                             "date": "2027-02-03",
#                             "value": 1.180784
#                         },
#                         {
#                             "date": "2027-05-03",
#                             "value": 1.184466
#                         },
#                         {
#                             "date": "2027-08-03",
#                             "value": 1.18816
#                         },
#                         {
#                             "date": "2027-11-03",
#                             "value": 1.191686
#                         },
#                         {
#                             "date": "2028-11-03",
#                             "value": 1.2056115
#                         },
#                         {
#                             "date": "2029-11-05",
#                             "value": 1.2194070000000001
#                         },
#                         {
#                             "date": "2030-11-04",
#                             "value": 1.23346
#                         },
#                         {
#                             "date": "2031-11-03",
#                             "value": 1.2482305
#                         },
#                         {
#                             "date": "2032-11-03",
#                             "value": 1.2657
#                         },
#                         {
#                             "date": "2033-11-03",
#                             "value": 1.2811000000000001
#                         },
#                         {
#                             "date": "2034-11-03",
#                             "value": 1.2933500000000002
#                         },
#                         {
#                             "date": "2035-11-05",
#                             "value": 1.31025
#                         },
#                         {
#                             "date": "2037-11-03",
#                             "value": 1.31025
#                         },
#                         {
#                             "date": "2040-11-05",
#                             "value": 1.31025
#                         },
#                         {
#                             "date": "2045-11-03",
#                             "value": 1.31025
#                         },
#                         {
#                             "date": "2050-11-03",
#                             "value": 1.31025
#                         },
#                         {
#                             "date": "2055-11-03",
#                             "value": 1.31025
#                         },
#                         {
#                             "date": "2065-11-03",
#                             "value": 1.31025
#                         },
#                         {
#                             "date": "2075-11-04",
#                             "value": 1.31025
#                         }
#                     ],
#                     "fxCrossCode": "EURUSD"
#                 }
#             },
#             {
#                 "curve": {
#                     "fxType": "Outright",
#                     "points": [
#                         {
#                             "date": "2025-11-04",
#                             "value": 0.8018564
#                         },
#                         {
#                             "date": "2025-11-10",
#                             "value": 0.8012995
#                         },
#                         {
#                             "date": "2025-11-17",
#                             "value": 0.800648
#                         },
#                         {
#                             "date": "2025-11-24",
#                             "value": 0.799998
#                         },
#                         {
#                             "date": "2025-12-03",
#                             "value": 0.799148
#                         },
#                         {
#                             "date": "2026-01-05",
#                             "value": 0.796017
#                         },
#                         {
#                             "date": "2026-02-03",
#                             "value": 0.793489
#                         },
#                         {
#                             "date": "2026-03-03",
#                             "value": 0.7911
#                         },
#                         {
#                             "date": "2026-04-07",
#                             "value": 0.7881485
#                         },
#                         {
#                             "date": "2026-05-04",
#                             "value": 0.785926
#                         },
#                         {
#                             "date": "2026-06-03",
#                             "value": 0.783449
#                         },
#                         {
#                             "date": "2026-07-03",
#                             "value": 0.78105
#                         },
#                         {
#                             "date": "2026-08-03",
#                             "value": 0.7786285
#                         },
#                         {
#                             "date": "2026-09-03",
#                             "value": 0.776269
#                         },
#                         {
#                             "date": "2026-10-05",
#                             "value": 0.77373
#                         },
#                         {
#                             "date": "2026-11-03",
#                             "value": 0.7717105
#                         },
#                         {
#                             "date": "2027-02-03",
#                             "value": 0.76465
#                         },
#                         {
#                             "date": "2027-05-03",
#                             "value": 0.7585
#                         },
#                         {
#                             "date": "2027-08-03",
#                             "value": 0.7521599999999999
#                         },
#                         {
#                             "date": "2027-11-03",
#                             "value": 0.74585
#                         },
#                         {
#                             "date": "2028-11-03",
#                             "value": 0.7215400000000001
#                         },
#                         {
#                             "date": "2029-11-05",
#                             "value": 0.69755
#                         },
#                         {
#                             "date": "2030-11-04",
#                             "value": 0.6746
#                         },
#                         {
#                             "date": "2031-11-03",
#                             "value": 0.6517499999999999
#                         },
#                         {
#                             "date": "2032-11-03",
#                             "value": 0.63035
#                         },
#                         {
#                             "date": "2033-11-03",
#                             "value": 0.6079
#                         },
#                         {
#                             "date": "2034-11-03",
#                             "value": 0.5865499999999999
#                         },
#                         {
#                             "date": "2035-11-05",
#                             "value": 0.5660499999999999
#                         },
#                         {
#                             "date": "2037-11-03",
#                             "value": 0.5660499999999999
#                         },
#                         {
#                             "date": "2040-11-05",
#                             "value": 0.5660499999999999
#                         },
#                         {
#                             "date": "2045-11-03",
#                             "value": 0.5660499999999999
#                         },
#                         {
#                             "date": "2050-11-03",
#                             "value": 0.5660499999999999
#                         },
#                         {
#                             "date": "2055-11-03",
#                             "value": 0.5660499999999999
#                         },
#                         {
#                             "date": "2065-11-03",
#                             "value": 0.5660499999999999
#                         },
#                         {
#                             "date": "2075-11-04",
#                             "value": 0.5660499999999999
#                         }
#                     ],
#                     "fxCrossCode": "USDCHF"
#                 }
#             },
#             {
#                 "curve": {
#                     "fxType": "Outright",
#                     "points": [],
#                     "fxCrossCode": "EURCHF"
#                 }
#             }
#         ]
#     }
# }
