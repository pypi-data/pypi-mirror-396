# %% [markdown]
# # rag-bencher quickstart\nRun from a notebook.

# %%
from rag_bencher.eval.dataset_loader import load_texts_as_documents
from rag_bencher.pipelines.naive_rag import build_chain
docs = load_texts_as_documents(['examples/data/sample.txt'])
chain = build_chain(docs)
chain.invoke('What is LangChain?')
